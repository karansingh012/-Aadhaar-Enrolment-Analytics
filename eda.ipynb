# %% [markdown]
# # Importing enrolment file1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df1 = pd.read_csv('/Users/karansingh/Desktop/Hackathon/DAtaHackathon/api_data_aadhar_enrolment_0_500000.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            500000 non-null  object
#  1   state           500000 non-null  object
#  2   district        500000 non-null  object
#  3   pincode         500000 non-null  int64
#  4   age_0_5         500000 non-null  int64
#  5   age_5_17        500000 non-null  int64
#  6   age_18_greater  500000 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 26.7+ MB

# %%
df1.shape
# Out:
# (500000, 7)

# %%
df1.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# date              object
# state             object
# district          object
# pincode            int64
# age_0_5            int64
# age_5_17           int64
# age_18_greater     int64
# dtype: object

# %%
df1['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
# ...

# %%
df1['new_date'] = pd.to_datetime(df1['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
df1
# Out:
#               date           state          district  pincode  age_0_5  \
# 0       02-03-2025       Meghalaya  East Khasi Hills   793121       11
# 1       09-03-2025       Karnataka   Bengaluru Urban   560043       14
# 2       09-03-2025   Uttar Pradesh      Kanpur Nagar   208001       29
# 3       09-03-2025   Uttar Pradesh           Aligarh   202133       62
# 4       09-03-2025       Karnataka   Bengaluru Urban   560016       14
# ...            ...             ...               ...      ...      ...
# 499995  26-10-2025  Andhra Pradesh       Mahbubnagar   509207        1
# 499996  26-10-2025  Andhra Pradesh             Medak   502220        1
# 499997  26-10-2025  Andhra Pradesh             Medak   502256        0
# 499998  26-10-2025  Andhra Pradesh             Medak   502286        1
# 499999  26-10-2025  Andhra Pradesh           N. T. R   521402        1
#
#         age_5_17  age_18_greater  new_date
# 0             61              37  20250302
# ...

# %%
df1['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df1['new_date'].min())
print(df1['new_date'].max())
# Out:
# 20250302
# 20251026

# %%
## check null value 
df1['state'].isnull().sum()
# Out:
# np.int64(0)

# %%
## check state column
df1['state'].nunique()
# Out:
# 54

# %%
df1['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
# ...

# %% [markdown]
# # Import enrolment file2

# %%
df2 = pd.read_csv('/Users/karansingh/Desktop/Hackathon/DAtaHackathon/api_data_aadhar_enrolment_500000_1000000.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            500000 non-null  object
#  1   state           500000 non-null  object
#  2   district        500000 non-null  object
#  3   pincode         500000 non-null  int64
#  4   age_0_5         500000 non-null  int64
#  5   age_5_17        500000 non-null  int64
#  6   age_18_greater  500000 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 26.7+ MB

# %%
df2.shape
# Out:
# (500000, 7)

# %%
df2.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
df2['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Bihar', 'Chandigarh', 'Sikkim', 'West Bangal',
#        'Dadra and Nagar Haveli', 'Daman and Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Jammu & Kashmir',
#        'andhra pradesh', 'Dadra & Nagar Haveli', 'Westbengal',
#        'Daman & Diu', 'WESTBENGAL', 'West bengal', 'West  Bengal',
#        'WEST BENGAL', '100000'], dtype=object)

# %%
df2['new_date']=pd.to_datetime(df2['date']).dt.strftime('%Y%m%d')
df2
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/548265193.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df2['new_date']=pd.to_datetime(df2['date']).dt.strftime('%Y%m%d')
#               date           state   district  pincode  age_0_5  age_5_17  \
# 0       26-10-2025  Andhra Pradesh   Nalgonda   508004        0         1
# 1       26-10-2025  Andhra Pradesh   Nalgonda   508238        1         0
# 2       26-10-2025  Andhra Pradesh   Nalgonda   508278        1         0
# 3       26-10-2025  Andhra Pradesh    Nandyal   518432        0         1
# 4       26-10-2025  Andhra Pradesh    Nandyal   518543        1         0
# ...            ...             ...        ...      ...      ...       ...
# 499995  31-12-2025       Telangana  Hyderabad   500045        4         5
# ...

# %%
df2['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df2['new_date'].min())
print(df2['new_date'].max())
# Out:
# 20251026
# 20251231

# %%
## check null value 
df2['state'].isnull().sum()
# Out:
# np.int64(0)

# %%
df2['state'].nunique()
# Out:
# 52

# %%
df2['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Bihar', 'Chandigarh', 'Sikkim', 'West Bangal',
#        'Dadra and Nagar Haveli', 'Daman and Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Jammu & Kashmir',
#        'andhra pradesh', 'Dadra & Nagar Haveli', 'Westbengal',
#        'Daman & Diu', 'WESTBENGAL', 'West bengal', 'West  Bengal',
#        'WEST BENGAL', '100000'], dtype=object)

# %% [markdown]
# # Import enrolment file 3

# %%
df3 = pd.read_csv('/Users/karansingh/Desktop/Hackathon/DAtaHackathon/api_data_aadhar_enrolment_1000000_1006029.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6029 entries, 0 to 6028
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6029 non-null   object
#  1   state           6029 non-null   object
#  2   district        6029 non-null   object
#  3   pincode         6029 non-null   int64
#  4   age_0_5         6029 non-null   int64
#  5   age_5_17        6029 non-null   int64
#  6   age_18_greater  6029 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 329.8+ KB

# %%
df3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
df3.shape
# Out:
# (6029, 7)

# %%
df3['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Pondicherry'], dtype=object)

# %%
df3['new_date']=pd.to_datetime(df3['date']).dt.strftime('%Y%m%d')
df3
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/880774394.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df3['new_date']=pd.to_datetime(df3['date']).dt.strftime('%Y%m%d')
#             date        state        district  pincode  age_0_5  age_5_17  \
# 0     31-12-2025    Karnataka           Bidar   585330        2         3
# 1     31-12-2025    Karnataka           Bidar   585402        6         0
# 2     31-12-2025    Karnataka           Bidar   585413        1         0
# 3     31-12-2025    Karnataka           Bidar   585418        1         2
# 4     31-12-2025    Karnataka           Bidar   585421        4         3
# ...          ...          ...             ...      ...      ...       ...
# 6024  31-12-2025  West Bengal  West Midnapore   721149        2         0
# ...

# %%
df3['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df3['new_date'].min())
print(df3['new_date'].max())
# Out:
# 20251231
# 20251231

# %%
## check null value 
df3['state'].isnull().sum()
# Out:
# np.int64(0)

# %%
## check state column
df3['state'].nunique()
# Out:
# 37

# %%
df3['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Pondicherry'], dtype=object)

# %% [markdown]
# ## Merging three datasets

# %%
df = pd.concat([df1,df2,df3],ignore_index=True)
df.shape
# Out:
# (1006029, 8)

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater  new_date
# 0              37  20250302
# 1              39  20250309
# 2              12  20250309
# 3              15  20250309
# 4              21  20250309

# %%
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['state'].value_counts()
# Out:
# state
# Uttar Pradesh                                   110369
# Tamil Nadu                                       92552
# Maharashtra                                      77191
# West Bengal                                      76519
# Karnataka                                        70198
# Andhra Pradesh                                   65658
# Bihar                                            60567
# Rajasthan                                        56159
# Madhya Pradesh                                   50225
# Gujarat                                          46624
# Odisha                                           43691
# Telangana                                        42774
# Kerala                                           39145
# Assam                                            31827
# Jharkhand                                        23218
# Punjab                                           20439
# Chhattisgarh                                     18550
# ...

# %%
df['state'].nunique()
# Out:
# 55

# %%
df['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
# ...

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x 
    x = str(x).lower()
    x = re.sub(r'[^a-z]', '', x) # remove symbols like &,
    x = re.sub(r'\s+',' ', x).strip() # remove extra spaces
    return x

# %%
state_mapping = {
    # Andhra Pradesh
    "andhrapradesh": "Andhra Pradesh",

    # Arunachal Pradesh
    "arunachalpradesh": "Arunachal Pradesh",

    # Assam
    "assam": "Assam",

    # Bihar
    "bihar": "Bihar",

    # Chhattisgarh
    "chhattisgarh": "Chhattisgarh",

    # Delhi
    "delhi": "Delhi",

    # Goa
    "goa": "Goa",

    # Gujarat
    "gujarat": "Gujarat",

    # Haryana
    "haryana": "Haryana",

    # Himachal Pradesh
    "himachalpradesh": "Himachal Pradesh",

    # Jammu & Kashmir / Ladakh
    "jammuandkashmir": "Jammu and Kashmir",
    "jammukashmir": "Jammu and Kashmir",

    "ladakh": "Ladakh",

    # Jharkhand
    "jharkhand": "Jharkhand",

    # Karnataka
    "karnataka": "Karnataka",

    # Kerala
    "kerala": "Kerala",

    # Madhya Pradesh
    "madhyapradesh": "Madhya Pradesh",

    # Maharashtra
    "maharashtra": "Maharashtra",

    # Manipur
    "manipur": "Manipur",

    # Meghalaya
    "meghalaya": "Meghalaya",

    # Mizoram
    "mizoram": "Mizoram",

    # Nagaland
    "nagaland": "Nagaland",

    # Odisha (Orissa old name)
    "odisha": "Odisha",
    "orissa": "Odisha",

    # Punjab
    "punjab": "Punjab",

    # Rajasthan
    "rajasthan": "Rajasthan",

    # Sikkim
    "sikkim": "Sikkim",

    # Tamil Nadu
    "tamilnadu": "Tamil Nadu",

    # Telangana
    "telangana": "Telangana",

    # Tripura
    "tripura": "Tripura",

    # Uttar Pradesh
    "uttarpradesh": "Uttar Pradesh",

    # Uttarakhand
    "uttarakhand": "Uttarakhand",

    # West Bengal (ALL variations including typo "Bangal")
    "westbengal": "West Bengal",
    "westbangal": "West Bengal",

    # Andaman & Nicobar Islands
    "andamannicobarislands": "Andaman and Nicobar Islands",
    "andamanandnicobarislands": "Andaman and Nicobar Islands",

    # Chandigarh
    "chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli / Daman & Diu (merged UT)
    "dadraandnagarhaveli": "Dadra and Nagar Haveli and Daman and Diu",
    "damananddiu": "Dadra and Nagar Haveli and Daman and Diu",
    "dadranagarhaveli": "Dadra and Nagar Haveli and Daman and Diu",
    "damandiu": "Dadra and Nagar Haveli and Daman and Diu",
    "dadraandnagarhavelianddamananddiu": "Dadra and Nagar Haveli and Daman and Diu",
    "thedadraandnagarhavelianddamananddiu": "Dadra and Nagar Haveli and Daman and Diu",

    # Lakshadweep
    "lakshadweep": "Lakshadweep",

    # Puducherry
    "pondicherry": "Puducherry",
    "puducherry": "Puducherry",
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries
df = df[~df['state'].astype(str).str.isnumeric()]

# check unmapped states
unmapped_states = df[df['state_clean'].isnull()]['state'].unique()
print("Unmapped States:", unmapped_states)
# Out:
# Unmapped States: []

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df['state_clean'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Arunachal Pradesh',
#        'Himachal Pradesh', 'Goa', 'Ladakh', 'Andaman and Nicobar Islands',
#        'Puducherry', 'Lakshadweep'], dtype=object)

# %%
df
# Out:
#                date          state          district  pincode  age_0_5  \
# 0        02-03-2025      Meghalaya  East Khasi Hills   793121       11
# 1        09-03-2025      Karnataka   Bengaluru Urban   560043       14
# 2        09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29
# 3        09-03-2025  Uttar Pradesh           Aligarh   202133       62
# 4        09-03-2025      Karnataka   Bengaluru Urban   560016       14
# ...             ...            ...               ...      ...      ...
# 1006024  31-12-2025    West Bengal    West Midnapore   721149        2
# 1006025  31-12-2025    West Bengal    West Midnapore   721150        2
# 1006026  31-12-2025    West Bengal    West Midnapore   721305        0
# 1006027  31-12-2025    West Bengal    West Midnapore   721504        1
# 1006028  31-12-2025    West Bengal    West Midnapore   721517        2
#
#          age_5_17  age_18_greater  new_date    state_clean
# ...

# %%
df.dtypes
# Out:
# date              object
# state             object
# district          object
# pincode            int64
# age_0_5            int64
# age_5_17           int64
# age_18_greater     int64
# new_date          object
# state_clean       object
# dtype: object

# %%
## total enrolment by state 
state_summary = df.groupby('state_clean')[[
    'age_0_5', 'age_5_17', 'age_18_greater'
]].sum()

state_summary['total_enrollment'] = (
    state_summary['age_0_5'] +
    state_summary['age_5_17'] +
    state_summary['age_18_greater']
)

top10_states = state_summary.sort_values(
    by='total_enrollment', ascending=False
).head(10)

# %%
state_summary
# Out:
#                                           age_0_5  age_5_17  age_18_greater  \
# state_clean
# Andaman and Nicobar Islands                   479        32               0
# Andhra Pradesh                             112445     13746            1495
# Arunachal Pradesh                            1957      2236             151
# Assam                                      141235     66085           22877
# Bihar                                      262875    334802           11908
# Chandigarh                                   2476       211              36
# Chhattisgarh                                82453     18769            1997
# Dadra and Nagar Haveli and Daman and Diu     1497       250              52
# Delhi                                       69183     22296            3050
# Goa                                          1916       254             163
# Gujarat                                    193031     71182           16336
# ...

# %% [markdown]
# # Bar chart → Top 10 states by total enrollment
# Top 10 states account for a significant share of total enrollments, indicating population concentration and higher enrollment activity

# %%
## bar plot for top 10 states
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.barplot(
    x=top10_states.index,
    y=top10_states['total_enrollment'],
    palette='viridis'
)
plt.title('Top 10 States by Total Aadhar Enrollments')
plt.xlabel('States')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3755885565.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# #  Children vs Adult Enrollment (Top 10 States)

# %%
top10_states['children_enrollment'] = (
    top10_states['age_0_5'] +
    top10_states['age_5_17']
)

# %% [markdown]
# # Stacked bar chart
# Certain states show a higher proportion of child enrollments, suggesting effective early-age registration drives.

# %%
# Stacked bar plot for age group comparison
plt.figure(figsize=(14,6))
top10_states[['children_enrollment', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Top 10 States: Children vs Adults Enrollment')
plt.xlabel('States')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Age Composition Percentage
# States with higher child enrollment percentages may indicate stronger newborn and school-level enrollment outreach.

# %%
top10_states['children_percent'] = (
    top10_states['children_enrollment'] /
    top10_states['total_enrollment']
) * 100

top10_states['adult_percent'] = (
    top10_states['age_18_greater'] /
    top10_states['total_enrollment']
) * 100

# %%
top10_states[['children_percent', 'adult_percent']]
# Out:
#                 children_percent  adult_percent
# state_clean
# Uttar Pradesh          98.242540       1.757460
# Bihar                  98.046540       1.953460
# Madhya Pradesh         98.056765       1.943235
# West Bengal            97.732722       2.267278
# Maharashtra            97.776176       2.223824
# Rajasthan              98.405834       1.594166
# Gujarat                94.177131       5.822869
# Assam                  90.061990       9.938010
# Karnataka              95.471140       4.528860
# Tamil Nadu             99.434302       0.565698

# %%
df_bihar= df[df['state_clean']=='Bihar']
df_bihar
# Out:
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date state_clean
# 5                    12  20250309       Bihar
# ...

# %% [markdown]
# # Bihar ke liye

# %%
df_bihar['district'].unique()
## yha pr district ki bhi mapping krni padegi
## Aurangabad(bh)', 'Purnea', 'Pashchim Champaran', 'Sheikpura',
    #    'Bhabua', 'Aurangabad(BH)'], dtype=object)) issko dekho
# Out:
# array(['Sitamarhi', 'Purbi Champaran', 'Madhubani', 'Bhagalpur', 'Patna',
#        'Pashchim Champaran', 'Muzaffarpur', 'Munger', 'Gaya',
#        'Kaimur (Bhabua)', 'West Champaran', 'Purnia', 'Saran',
#        'East Champaran', 'Vaishali', 'Jehanabad', 'Jamui', 'Gopalganj',
#        'Saharsa', 'Arwal', 'Katihar', 'Siwan', 'Lakhisarai', 'Banka',
#        'Nalanda', 'Araria', 'Darbhanga', 'Nawada', 'Samastipur',
#        'Begusarai', 'Bhojpur', 'Aurangabad', 'Buxar', 'Khagaria',
#        'Kishanganj', 'Madhepura', 'Rohtas', 'Sheohar', 'Supaul',
#        'Aurangabad(bh)', 'Purba Champaran', 'Purnea', 'Sheikhpura',
#        'Sheikpura', 'Bhabua', 'Monghyr', 'Samstipur', 'Aurangabad(BH)'],
#       dtype=object)

# %%
df_bihar['district'].nunique()
# Out:
# 48

# %%
import pandas as pd
import re

def clean_name(x):
    if pd.isna(x):
        return x 
    x = str(x).lower()
    x = re.sub(r'[^a-z]', '', x) 
    x = re.sub(r'\s+',' ', x).strip()
    return x

# %%
## District mapping bihar 
bihar_district_mapping = {

    # Arwal
    "arwal": "Arwal",

    # Aurangabad
    "aurangabad": "Aurangabad",
    "aurangabadbh": "Aurangabad",

    # Araria
    "araria": "Araria",

    # Banka
    "banka": "Banka",

    # Begusarai
    "begusarai": "Begusarai",

    # Bhagalpur
    "bhagalpur": "Bhagalpur",

    # Bhojpur
    "bhojpur": "Bhojpur",

    # Buxar
    "buxar": "Buxar",

    # Darbhanga
    "darbhanga": "Darbhanga",

    # East Champaran
    "eastchamparan": "East Champaran",
    "purbachamparan": "East Champaran",

    # West Champaran
    "westchamparan": "West Champaran",
    "pashchimchamparan": "West Champaran",

    # Gaya
    "gaya": "Gaya",

    # Gopalganj
    "gopalganj": "Gopalganj",

    # Jamui
    "jamui": "Jamui",

    # Jehanabad
    "jehanabad": "Jehanabad",

    # Kaimur
    "kaimurbhabua": "Kaimur",
    "bhabua": "Kaimur",

    # Katihar
    "katihar": "Katihar",

    # Khagaria
    "khagaria": "Khagaria",

    # Kishanganj
    "kishanganj": "Kishanganj",

    # Lakhisarai
    "lakhisarai": "Lakhisarai",

    # Madhepura
    "madhepura": "Madhepura",

    # Madhubani
    "madhubani": "Madhubani",

    # Munger
    "munger": "Munger",
    "monghyr": "Munger",

    # Muzaffarpur
    "muzaffarpur": "Muzaffarpur",

    # Nalanda
    "nalanda": "Nalanda",

    # Nawada
    "nawada": "Nawada",

    # Patna
    "patna": "Patna",

    # Purnia
    "purnia": "Purnia",
    "purnea": "Purnia",

    # Rohtas
    "rohtas": "Rohtas",

    # Saharsa
    "saharsa": "Saharsa",

    # Samastipur
    "samastipur": "Samastipur",
    "samstipur": "Samastipur",

    # Saran
    "saran": "Saran",

    # Sheikhpura
    "sheikhpura": "Sheikhpura",
    "sheikpura": "Sheikhpura",

    # Sheohar
    "sheohar": "Sheohar",

    # Sitamarhi
    "sitamarhi": "Sitamarhi",

    # Siwan
    "siwan": "Siwan",

    # Supaul
    "supaul": "Supaul",

    # Vaishali
    "vaishali": "Vaishali",
}

# %%
df['district_clean'] = (
    df['district']
    .apply(clean_name)
    .map(bihar_district_mapping)
    .fillna(df_bihar['district'])

)

# %%
## Remaining unmapped
df[df['district_clean'].isna()]['district'].unique()
# count check 
df['district_clean'].nunique()
# Out:
# 39

# %%
df_bihar = df[df['state_clean']=='Bihar']
df_bihar
# Out:
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date state_clean   district_clean
# ...

# %%
# Check Bihar-specific unmapped districts
df_bihar_unmapped = df_bihar[df_bihar['district_clean'].isna()]
print(f"Unmapped Bihar districts count: {len(df_bihar_unmapped)}")
df_bihar_unmapped['district'].unique()
# Out:
# Unmapped Bihar districts count: 0
# array([], dtype=object)

# %%
df_bihar['district_clean'].unique()
# Out:
# array(['Sitamarhi', 'Purbi Champaran', 'Madhubani', 'Bhagalpur', 'Patna',
#        'West Champaran', 'Muzaffarpur', 'Munger', 'Gaya', 'Kaimur',
#        'Purnia', 'Saran', 'East Champaran', 'Vaishali', 'Jehanabad',
#        'Jamui', 'Gopalganj', 'Saharsa', 'Arwal', 'Katihar', 'Siwan',
#        'Lakhisarai', 'Banka', 'Nalanda', 'Araria', 'Darbhanga', 'Nawada',
#        'Samastipur', 'Begusarai', 'Bhojpur', 'Aurangabad', 'Buxar',
#        'Khagaria', 'Kishanganj', 'Madhepura', 'Rohtas', 'Sheohar',
#        'Supaul', 'Sheikhpura'], dtype=object)

# %%
df_bihar.dtypes
# Out:
# date              object
# state             object
# district          object
# pincode            int64
# age_0_5            int64
# age_5_17           int64
# age_18_greater     int64
# new_date          object
# state_clean       object
# district_clean    object
# dtype: object

# %%
df_bihar['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# unique pincodes in bihar
df_bihar['pincode'].nunique()
# Out:
# 906

# %%
pincode_check = df_bihar.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincodes')
pincode_check
# Out:
#      district_clean  unique_pincodes
# 0            Araria               19
# 1             Arwal               19
# 2        Aurangabad               29
# 3             Banka               32
# 4         Begusarai               33
# 5         Bhagalpur               34
# 6           Bhojpur               41
# 7             Buxar               27
# 8         Darbhanga               46
# 9    East Champaran               39
# 10             Gaya               39
# 11        Gopalganj               23
# 12            Jamui               14
# 13        Jehanabad               21
# 14           Kaimur               12
# 15          Katihar               23
# 16         Khagaria               15
# 17       Kishanganj                9
# 18       Lakhisarai               13
# 19        Madhepura               21
# 20        Madhubani               44
# 21           Munger               12
# 22      Muzaffarpur               53
# 23          Nalanda               31
# ...

# %%
df_bihar[df_bihar['district_clean']=='Kaimur']['pincode'].unique()
# Out:
# array([821106, 821108, 821109, 821105, 821110, 802132, 821101, 821102,
#        821104, 821103, 821112, 821311])

# %%
pin_district_count = (
    df_bihar.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     800001               1
# 1     800002               1
# 2     800003               1
# 3     800004               1
# 4     800005               1
# ..       ...             ...
# 901   855114               1
# 902   855115               2
# 903   855116               1
# 904   855117               1
# 905   855456               1
#
# [906 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
## ek pin code 2 district se belong kr skta hai theek ye govt ki website pr hai
# Out:
#      pincode  district_count
# 40    801304               2
# 41    801305               2
# 53    802112               2
# 73    802134               2
# 83    802160               2
# ..       ...             ...
# 890   854337               2
# 894   855101               3
# 896   855105               2
# 898   855107               2
# 902   855115               2
#
# [177 rows x 2 columns]

# %%
df_flagged = df_bihar.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
## ye sab o hai jissme ek district ke 2 pincode hai
## yha se hum pta kr skte hai kiss district me jda use ho rha hai 
df_flagged
# Out:
#              date  state         district  pincode  age_0_5  age_5_17  \
# 0      09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 1      09-03-2025  Bihar  Purbi Champaran   845304       18        72
# 2      15-03-2025  Bihar  Purbi Champaran   845303       12       121
# 3      01-04-2025  Bihar        Sitamarhi   843315      102       125
# 4      01-04-2025  Bihar           Munger   811213      191       278
# ...           ...    ...              ...      ...      ...       ...
# 16964  31-12-2025  Bihar          Sheohar   843325        4         2
# 16965  31-12-2025  Bihar        Sitamarhi   843325       11         6
# 16966  31-12-2025  Bihar            Siwan   841243        2        11
# 16967  31-12-2025  Bihar           Supaul   852108        0         9
# 16968  31-12-2025  Bihar           Supaul   852131       15        19
#
#        age_18_greater  new_date state_clean   district_clean
# 0                  10  20250309       Bihar  Purbi Champaran
# ...

# %%
flagged_pincode=df_flagged.groupby(['district_clean','pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()
#flagged_pincode.to_excel('flagged_pincode_domain.xlsx')

# %%
flagged_pincode['total_enrollment']=flagged_pincode['age_0_5']+flagged_pincode['age_5_17']+flagged_pincode['age_18_greater']
flagged_pincode
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 0           Araria   854102      131        86               1
# 1           Araria   854201       31        33               0
# 2           Araria   854202       58        74               0
# 3           Araria   854304      410       412              14
# 4           Araria   854312      837       546               6
# ..             ...      ...      ...       ...             ...
# 360       Vaishali   843104       66        37               0
# 361       Vaishali   843105        7         2               0
# 362       Vaishali   844111      153       188               0
# 363       Vaishali   844112      181       195               1
# 364       Vaishali   844120       22        30               0
#
#      total_enrollment
# 0                 218
# 1                  64
# 2                 132
# 3                 836
# 4                1389
# ..                ...
# 360               103
# ...

# %%
## isse pta chlega hai kiss pincode me jda aadhar enrolment ho rha hai is pin code pr 
## baad me agr jarurat pde too hum iska flag bna skte hai ki jo bhi district 
## same pin code se hai usse true ur jo ek hi pincode se hai usse false

# %%
idx = flagged_pincode.groupby('pincode')['total_enrollment'].idxmax()
df_filtered = flagged_pincode.loc[idx]
df_filtered
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 223        Nalanda   801304       58       114               0
# 224        Nalanda   801305       39        62               1
# 63           Buxar   802112      117       224               1
# 64           Buxar   802134      125       370               1
# 59         Bhojpur   802160       66       273               2
# ..             ...      ...      ...       ...             ...
# 281         Purnia   854337      336       131               0
# 165     Kishanganj   855101     1906       357               7
# 158        Katihar   855105      386       125               6
# 166     Kishanganj   855107     1685       446               1
# 167     Kishanganj   855115      774       208               4
#
#      total_enrollment
# 223               172
# 224               102
# 63                342
# 64                496
# 59                341
# ..                ...
# 281               467
# ...

# %%
df_bihar['pin_multi_district_flag']=(
    df_bihar.groupby('pincode')['district_clean']
    .transform('nunique')>1
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1858231122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['pin_multi_district_flag']=(

# %%
pin_district_map= (
    df_bihar[df_bihar['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']  # noqa: SC100
    .unique()
    .reset_index()
)

# %%
## monthly enrolment check 
df_bihar['month'] = df_bihar['new_date'].astype(str).str[4:6]
df_bihar
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/2055184884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['month'] = df_bihar['new_date'].astype(str).str[4:6]
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# ...

# %%
df_bihar_cleaned=df_bihar.drop(columns=['date','district','state'], axis=1)
df_bihar_cleaned
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date state_clean  \
# 5         843331       20        49              12  20250309       Bihar
# 6         843330       23        24              42  20250309       Bihar
# 9         845418       30        48              10  20250309       Bihar
# 11        843317       35        94              16  20250309       Bihar
# 13        843324       49       186              34  20250309       Bihar
# ...          ...      ...       ...             ...       ...         ...
# 1002992   844134        2         0               0  20251231       Bihar
# 1002993   844504       15        26               1  20251231       Bihar
# 1002994   844509        1         2               0  20251231       Bihar
# 1002995   845404       13        17               1  20251231       Bihar
# 1002996   845449        9        45               0  20251231       Bihar
#
#           district_clean  pin_multi_district_flag month
# ...

# %%
df_bihar_dist_level = df_bihar_cleaned.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()
df_bihar_dist_level['total_enrollment'] = df_bihar_dist_level['age_0_5'] + df_bihar_dist_level['age_5_17'] + df_bihar_dist_level['age_18_greater']

# %%
df_bihar_dist_level.shape
# Out:
# (39, 4)

# %%
df_bihar_dist_level
# Out:
#                  age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Araria              9939      5515             125             15579
# Arwal                812      3020              34              3866
# Aurangabad          3050      7160              73             10283
# Banka               6198      4797              79             11074
# Begusarai           8106      5045              58             13209
# Bhagalpur          10456     10229             377             21062
# Bhojpur             3136     10115             106             13357
# Buxar               2528      4648              64              7240
# Darbhanga          10017      5677              71             15765
# East Champaran     10208     18437             805             29450
# Gaya                6722     20244             435             27401
# Gopalganj           5303      9649             196             15148
# ...

# %%
df_bihar_dist_level.sort_values("total_enrollment",ascending=False).reset_index()
# df_bihar_dist_level.to_excel('bihar_district_level_enrolment.xlsx')
# Out:
#      district_clean  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0    West Champaran    16645     28807            1345             46797
# 1         Sitamarhi    20679     18856            2697             42232
# 2    East Champaran    10208     18437             805             29450
# 3       Muzaffarpur    14087     14103             665             28855
# 4              Gaya     6722     20244             435             27401
# 5         Madhubani    12598     12534             798             25930
# 6             Patna     6745     17151             748             24644
# 7             Saran     7592     16407             219             24218
# 8         Bhagalpur    10456     10229             377             21062
# 9            Purnia    12364      7809             184             20357
# 10       Samastipur    11330      7828             131             19289
# 11         Vaishali     8257      9698              52             18007
# ...

# %%
df_bihar_dist_level1 = df_bihar_dist_level.head(10)
df_bihar_dist_level1
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Araria             9939      5515             125             15579
# Arwal               812      3020              34              3866
# Aurangabad         3050      7160              73             10283
# Banka              6198      4797              79             11074
# Begusarai          8106      5045              58             13209
# Bhagalpur         10456     10229             377             21062
# Bhojpur            3136     10115             106             13357
# Buxar              2528      4648              64              7240
# Darbhanga         10017      5677              71             15765
# East Champaran    10208     18437             805             29450

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.lineplot(data=df_bihar_dist_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Districts in Bihar - Age Group Enrollment Comparison')
plt.xlabel('Districts')
plt.ylabel('Number of Enrollments')
plt.legend(title='Age Groups', labels=['Age 0-5', 'Age 5-17', 'Age 18 and above'])
plt.xticks(ticks=range(len(df_bihar_dist_level1.index)), labels=df_bihar_dist_level1.index, rotation=45)
plt.show()

# %%
df_bihar_pincode_level = df_bihar_cleaned.groupby('pincode')[['age_0_5','age_5_17','age_18_greater']].sum()
df_bihar_pincode_level['total_enrollment'] = df_bihar_pincode_level['age_0_5'] + df_bihar_pincode_level['age_5_17'] + df_bihar_pincode_level['age_18_greater']
df_bihar_pincode_level.shape
# Out:
# (906, 4)

# %%
df_bihar_pincode_level.sort_values("total_enrollment",ascending=False).reset_index()
# df_bihar_pincode_level.to_excel('bihar_pincode_level_enrolment.xlsx')
# Out:
#      pincode  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0     845438     3106      4959             148              8213
# 1     843302     3613      3415             144              7172
# 2     843324     3242      2970             803              7015
# 3     845401     1524      3778              70              5372
# 4     845455     1853      2895             213              4961
# ..       ...      ...       ...             ...               ...
# 901   800028        0         1               0                 1
# 902   813214        0         1               0                 1
# 903   813124        0         1               0                 1
# 904   800005        1         0               0                 1
# 905   844103        1         0               0                 1
#
# [906 rows x 5 columns]

# %%
df_bihar_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 800001       479      1553             126              2158
# 800002       138       482              26               646
# 800003        22        78               4               104
# 800004       100       221              22               343
# 800005         1         0               0                 1
# ...          ...       ...             ...               ...
# 855114       348       146               2               496
# 855115       996       268               4              1268
# 855116       652       189               2               843
# 855117      1049       329               2              1380
# 855456        10         3               0                13
#
# [906 rows x 4 columns]

# %%
df_bihar_pincode_level1 = df_bihar_pincode_level.head(10)
df_bihar_pincode_level1
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 800001       479      1553             126              2158
# 800002       138       482              26               646
# 800003        22        78               4               104
# 800004       100       221              22               343
# 800005         1         0               0                 1
# 800006       116       396              52               564
# 800007       171       463              40               674
# 800008       208       608              57               873
# 800009        72       183               8               263
# 800010        26        61               0                87

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=df_bihar_pincode_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Pincodes in Bihar - Age Group Enrollment Comparison')
plt.xlabel('Pincodes')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## monthly enrolment trend in bihar
df_bihar_monthly = df_bihar_cleaned.groupby('month')[['age_0_5','age_5_17','age_18_greater']].sum()
df_bihar_monthly['total_enrollment'] = df_bihar_monthly['age_0_5'] + df_bihar_monthly['age_5_17'] + df_bihar_monthly['age_18_greater']
df_bihar_monthly.shape
# Out:
# (9, 4)

# %%
df_bihar_monthly
df_bihar_monthly.sort_values("total_enrollment",ascending=False).reset_index()
# Out:
#   month  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0    09    62940     79583            1042            143565
# 1    11    48127     56444            1053            105624
# 2    10    46297     52921            1691            100909
# 3    12    44025     45700             657             90382
# 4    07    19008     38019            2247             59274
# 5    06    16160     28223            2003             46386
# 6    05    13251     17159            1241             31651
# 7    04    12551     15361            1530             29442
# 8    03      516      1392             444              2352

# %%
sns.lineplot(data=df_bihar_monthly)
# Out:
# <Axes: xlabel='month'>

# %%
## Stacked bar plot for age group comparison
plt.figure(figsize=(10,6))
df_bihar_monthly[['age_0_5', 'age_5_17', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Bihar Monthly Aadhar Enrollments by Age Group')
plt.xlabel('Month')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## adult vs children enrolment in bihar
df_bihar_monthly['children_enrollment'] = (
    df_bihar_monthly['age_0_5'] +
    df_bihar_monthly['age_5_17']
)
df_bihar_monthly
# Out:
#        age_0_5  age_5_17  age_18_greater  total_enrollment  \
# month
# 03         516      1392             444              2352
# 04       12551     15361            1530             29442
# 05       13251     17159            1241             31651
# 06       16160     28223            2003             46386
# 07       19008     38019            2247             59274
# 09       62940     79583            1042            143565
# 10       46297     52921            1691            100909
# 11       48127     56444            1053            105624
# 12       44025     45700             657             90382
#
#        children_enrollment
# month
# 03                    1908
# 04                   27912
# 05                   30410
# 06                   44383
# 07                   57027
# 09                  142523
# 10                   99218
# 11                  104571
# 12                   89725

# %%
## bar plot for adult vs children enrolment in bihar
plt.figure(figsize=(10,6))
df_bihar_monthly[['children_enrollment', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'      
)
plt.title('Bihar Monthly Aadhar Enrollments: Children vs Adults')
plt.xlabel('Month')
plt.ylabel('Number of Enrollments') 
plt.show()

# %% [markdown]
# # Uttar Pradesh ke liye

# %%
df_uttarpradesh= df[df['state_clean']=='Uttar Pradesh']
df_uttarpradesh
# Out:
#                date          state      district  pincode  age_0_5  age_5_17  \
# 2        09-03-2025  Uttar Pradesh  Kanpur Nagar   208001       29        82
# 3        09-03-2025  Uttar Pradesh       Aligarh   202133       62        29
# 7        09-03-2025  Uttar Pradesh      Bahraich   271865       26        60
# 8        09-03-2025  Uttar Pradesh     Firozabad   283204       28        26
# 10       09-03-2025  Uttar Pradesh   Maharajganj   273164       31        70
# ...             ...            ...           ...      ...      ...       ...
# 1005743  31-12-2025  Uttar Pradesh      Varanasi   221002       10        18
# 1005744  31-12-2025  Uttar Pradesh      Varanasi   221104        4        11
# 1005745  31-12-2025  Uttar Pradesh      Varanasi   221107        1        15
# 1005746  31-12-2025  Uttar Pradesh      Varanasi   221207        1         9
# 1005747  31-12-2025  Uttar Pradesh      Varanasi   221313        1         0
#
# ...

# %%
df_uttarpradesh['district'].unique()
# Out:
# array(['Kanpur Nagar', 'Aligarh', 'Bahraich', 'Firozabad', 'Maharajganj',
#        'Ghaziabad', 'Gautam Buddha Nagar', 'Lucknow', 'Agra', 'Unnao',
#        'Saharanpur', 'Jaunpur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Banda', 'Kheri', 'Budaun', 'Kanpur Dehat', 'Varanasi', 'Baghpat',
#        'Fatehpur', 'Etawah', 'Shamli', 'Balrampur', 'Bara Banki',
#        'Shahjahanpur', 'Gonda', 'Bareilly', 'Sitapur', 'Sultanpur',
#        'Shrawasti', 'Chandauli', 'Mainpuri', 'Muzaffarnagar',
#        'Siddharthnagar', 'Ambedkar Nagar', 'Pilibhit', 'Kaushambi',
#        'Jalaun', 'Etah', 'Meerut', 'Basti', 'Azamgarh', 'Rampur',
#        'Moradabad', 'Amroha', 'Bijnor', 'Deoria', 'Prayagraj', 'Lalitpur',
#        'Hapur', 'Hathras', 'Kushinagar', 'Shravasti', 'Farrukhabad',
#        'Hardoi', 'Ayodhya', 'Siddharth Nagar', 'Barabanki', 'Sambhal',
#        'Jhansi', 'Kasganj', 'Kannauj', 'Kushi Nagar', 'Allahabad',
# ...

# %%
df_uttarpradesh['district'].nunique()
# Out:
# 89

# %%
df_uttarpradesh['district_clean'] = (
    df_uttarpradesh['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\*', '', regex=True)
    .str.replace(r'\(.*?\)', '', regex=True)
    .str.replace(r'[^a-z\s]', '', regex=True)
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1172066687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uttarpradesh['district_clean'] = (

# %% [markdown]
# District names contained spelling variations and legacy names.
# A canonical district mapping was applied to standardize district identities
# before analysis, preventing double counting.

# %%
district_standard_map = {
    "bara banki": "Barabanki",
    "barabanki": "Barabanki",

    "bulandshahar": "Bulandshahr",
    "bulandshahr": "Bulandshahr",

    "siddharth nagar": "Siddharthnagar",
    "siddharthnagar": "Siddharthnagar",

    "kushi nagar": "Kushinagar",
    "kushinagar *": "Kushinagar",
    "kushinagar": "Kushinagar",

    "shrawasti": "Shravasti",
    "shravasti": "Shravasti",

    "mahrajganj": "Maharajganj",
    "maharajganj": "Maharajganj",

    "sant ravidas nagar bhadohi": "Bhadohi",
    "sant ravidas nagar": "Bhadohi",
    "bhadohi": "Bhadohi",

    "jyotiba phule nagar": "Amroha",
    "amroha": "Amroha",

    "allahabad": "Prayagraj",
    "prayagraj": "Prayagraj",

    "faizabad": "Ayodhya",
    "ayodhya": "Ayodhya",

    "rae bareli": "Raebareli",
    "raebareli": "Raebareli",

    "bagpat": "Baghpat",
    "baghpat": "Baghpat"
}

# %%
df_uttarpradesh['district_clean'] = (
    df['district']
    .apply(clean_name)
    .map(district_standard_map)
    .fillna(df_uttarpradesh['district'])

)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/973221572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uttarpradesh['district_clean'] = (

# %%
## Remaining unmapped
df_uttarpradesh[df_uttarpradesh['district_clean'].isna()]['district'].unique()
# count check 
df_uttarpradesh['district_clean'].nunique()
# Out:
# 78

# %%
df_uttarpradesh.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# new_date          0
# state_clean       0
# district_clean    0
# dtype: int64

# %%
df_uttarpradesh
# Out:
#                date          state      district  pincode  age_0_5  age_5_17  \
# 2        09-03-2025  Uttar Pradesh  Kanpur Nagar   208001       29        82
# 3        09-03-2025  Uttar Pradesh       Aligarh   202133       62        29
# 7        09-03-2025  Uttar Pradesh      Bahraich   271865       26        60
# 8        09-03-2025  Uttar Pradesh     Firozabad   283204       28        26
# 10       09-03-2025  Uttar Pradesh   Maharajganj   273164       31        70
# ...             ...            ...           ...      ...      ...       ...
# 1005743  31-12-2025  Uttar Pradesh      Varanasi   221002       10        18
# 1005744  31-12-2025  Uttar Pradesh      Varanasi   221104        4        11
# 1005745  31-12-2025  Uttar Pradesh      Varanasi   221107        1        15
# 1005746  31-12-2025  Uttar Pradesh      Varanasi   221207        1         9
# 1005747  31-12-2025  Uttar Pradesh      Varanasi   221313        1         0
#
# ...

# %%
## total enrolment by district in uttar pradesh
df_uttarpradesh_dist_level = df_uttarpradesh.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()

# %%
df_uttarpradesh['total_enrollment'] = (
    df_uttarpradesh['age_0_5'] +
    df_uttarpradesh['age_5_17'] +
    df_uttarpradesh['age_18_greater']
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1685002294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uttarpradesh['total_enrollment'] = (

# %%
df_uttarpradesh
# Out:
#                date          state      district  pincode  age_0_5  age_5_17  \
# 2        09-03-2025  Uttar Pradesh  Kanpur Nagar   208001       29        82
# 3        09-03-2025  Uttar Pradesh       Aligarh   202133       62        29
# 7        09-03-2025  Uttar Pradesh      Bahraich   271865       26        60
# 8        09-03-2025  Uttar Pradesh     Firozabad   283204       28        26
# 10       09-03-2025  Uttar Pradesh   Maharajganj   273164       31        70
# ...             ...            ...           ...      ...      ...       ...
# 1005743  31-12-2025  Uttar Pradesh      Varanasi   221002       10        18
# 1005744  31-12-2025  Uttar Pradesh      Varanasi   221104        4        11
# 1005745  31-12-2025  Uttar Pradesh      Varanasi   221107        1        15
# 1005746  31-12-2025  Uttar Pradesh      Varanasi   221207        1         9
# 1005747  31-12-2025  Uttar Pradesh      Varanasi   221313        1         0
#
# ...

# %%
# enrolment top 10 district 
df_district_level = df_uttarpradesh["district_clean"].head(10)

# %%
## total enrolment by district in uttar pradesh
state_summary2 = df_uttarpradesh.groupby('district_clean')[[
    'age_0_5', 'age_5_17', 'age_18_greater'
]].sum() ## means of all age group by district

state_summary2['total_enrollment'] = (
    state_summary2['age_0_5'] +
    state_summary2['age_5_17'] +
    state_summary2['age_18_greater'] ## total enrolment by district
)

top10_districts = state_summary2.sort_values(
    by='total_enrollment', ascending=False
).head(10)

# %%
## bar plot for top 10 states
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.barplot(
    x=top10_districts.index,
    y=top10_districts['total_enrollment'],
    palette='viridis'
)
plt.title('Top 10 Districts by Total Aadhar Enrollments in Uttar Pradesh')
plt.xlabel('Districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3726560018.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top10_districts['children_enrollment'] = (
    top10_districts['age_0_5'] +
    top10_districts['age_5_17']
)

# %%
# Stacked bar plot for age group comparison
plt.figure(figsize=(14,6))
top10_districts[['children_enrollment', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Top 10 districts: Children vs Adults Enrollment')
plt.xlabel('districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_uttarpradesh['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
pincode_check_UP = df_uttarpradesh.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincodes')
pincode_check_UP
# Out:
#     district_clean  unique_pincodes
# 0             Agra               29
# 1          Aligarh               39
# 2   Ambedkar Nagar               34
# 3           Amethi               39
# 4           Amroha               14
# ..             ...              ...
# 73         Sitapur               25
# 74       Sonbhadra               20
# 75       Sultanpur               35
# 76           Unnao               31
# 77        Varanasi               42
#
# [78 rows x 2 columns]

# %%
pin_district_count_UP = (
    df_uttarpradesh.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count_UP
# Out:
#       pincode  district_count
# 0      121705               1
# 1      201001               2
# 2      201002               2
# 3      201003               1
# 4      201004               1
# ...       ...             ...
# 1732   285203               1
# 1733   285204               1
# 1734   285205               2
# 1735   285206               1
# 1736   285223               2
#
# [1737 rows x 2 columns]

# %%
problem_pins_UP = pin_district_count_UP[
    pin_district_count_UP['district_count'] > 1
]

# %%
problem_pins_UP
## ek pin code 2 district se belong kr skta hai theek ye govt ki website pr hai
# Out:
#       pincode  district_count
# 1      201001               2
# 2      201002               2
# 5      201005               2
# 6      201006               2
# 7      201007               2
# ...       ...             ...
# 1713   284403               2
# 1724   285125               2
# 1725   285126               2
# 1734   285205               2
# 1736   285223               2
#
# [276 rows x 2 columns]

# %%
df_flagged_UP = df_uttarpradesh.merge(
    problem_pins_UP[['pincode']],
    on='pincode',
    how='inner'
)

# %%
## ye sab o hai jissme ek district ke 2 pincode hai
## yha se hum pta kr skte hai kiss district me jda use ho rha hai 
df_flagged_UP
# Out:
#              date          state        district  pincode  age_0_5  age_5_17  \
# 0      09-03-2025  Uttar Pradesh    Kanpur Nagar   208001       29        82
# 1      09-03-2025  Uttar Pradesh        Bahraich   271865       26        60
# 2      09-03-2025  Uttar Pradesh       Ghaziabad   201102       50       113
# 3      15-03-2025  Uttar Pradesh       Ghaziabad   201001       33       125
# 4      15-03-2025  Uttar Pradesh       Ghaziabad   201102       19       146
# ...           ...            ...             ...      ...      ...       ...
# 23723  31-12-2025  Uttar Pradesh  Siddharthnagar   272152        3        31
# 23724  31-12-2025  Uttar Pradesh       Sultanpur   227806        3         2
# 23725  31-12-2025  Uttar Pradesh       Sultanpur   227808        9        11
# 23726  31-12-2025  Uttar Pradesh           Unnao   209801       25        65
# 23727  31-12-2025  Uttar Pradesh           Unnao   241504       26        32
#
# ...

# %%
flagged_pincode_UP=df_flagged.groupby(['district_clean','pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()
#flagged_pincode.to_excel('flagged_pincode_domain.xlsx')

# %%
flagged_pincode_UP['total_enrollment']=flagged_pincode_UP['age_0_5']+flagged_pincode_UP['age_5_17']+flagged_pincode_UP['age_18_greater']
flagged_pincode_UP
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 0           Araria   854102      131        86               1
# 1           Araria   854201       31        33               0
# 2           Araria   854202       58        74               0
# 3           Araria   854304      410       412              14
# 4           Araria   854312      837       546               6
# ..             ...      ...      ...       ...             ...
# 360       Vaishali   843104       66        37               0
# 361       Vaishali   843105        7         2               0
# 362       Vaishali   844111      153       188               0
# 363       Vaishali   844112      181       195               1
# 364       Vaishali   844120       22        30               0
#
#      total_enrollment
# 0                 218
# 1                  64
# 2                 132
# 3                 836
# 4                1389
# ..                ...
# 360               103
# ...

# %%
idx = flagged_pincode_UP.groupby('pincode')['total_enrollment'].idxmax()
df_filtered_UP = flagged_pincode_UP.loc[idx]
df_filtered_UP
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 223        Nalanda   801304       58       114               0
# 224        Nalanda   801305       39        62               1
# 63           Buxar   802112      117       224               1
# 64           Buxar   802134      125       370               1
# 59         Bhojpur   802160       66       273               2
# ..             ...      ...      ...       ...             ...
# 281         Purnia   854337      336       131               0
# 165     Kishanganj   855101     1906       357               7
# 158        Katihar   855105      386       125               6
# 166     Kishanganj   855107     1685       446               1
# 167     Kishanganj   855115      774       208               4
#
#      total_enrollment
# 223               172
# 224               102
# 63                342
# 64                496
# 59                341
# ..                ...
# 281               467
# ...

# %%
df_uttarpradesh['pin_multi_district_flag']=(
    df_uttarpradesh.groupby('pincode')['district_clean']
    .transform('nunique')>1
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/2731928923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uttarpradesh['pin_multi_district_flag']=(

# %%
pin_district_map_UP = (
    df_uttarpradesh[df_uttarpradesh['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']  # noqa: SC100
    .unique()
    .reset_index()
)

# %%
## monthly enrolment check 
df_uttarpradesh['month'] = df_uttarpradesh['new_date'].astype(str).str[4:6]
df_uttarpradesh
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3194271396.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uttarpradesh['month'] = df_uttarpradesh['new_date'].astype(str).str[4:6]
#                date          state      district  pincode  age_0_5  age_5_17  \
# 2        09-03-2025  Uttar Pradesh  Kanpur Nagar   208001       29        82
# 3        09-03-2025  Uttar Pradesh       Aligarh   202133       62        29
# 7        09-03-2025  Uttar Pradesh      Bahraich   271865       26        60
# 8        09-03-2025  Uttar Pradesh     Firozabad   283204       28        26
# 10       09-03-2025  Uttar Pradesh   Maharajganj   273164       31        70
# ...

# %%
df_uttarpradesh_cleaned_UP=df_uttarpradesh.drop(columns=['date','district','state'], axis=1)
df_uttarpradesh_cleaned_UP
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date    state_clean  \
# 2         208001       29        82              12  20250309  Uttar Pradesh
# 3         202133       62        29              15  20250309  Uttar Pradesh
# 7         271865       26        60              14  20250309  Uttar Pradesh
# 8         283204       28        26              10  20250309  Uttar Pradesh
# 10        273164       31        70              13  20250309  Uttar Pradesh
# ...          ...      ...       ...             ...       ...            ...
# 1005743   221002       10        18               0  20251231  Uttar Pradesh
# 1005744   221104        4        11               0  20251231  Uttar Pradesh
# 1005745   221107        1        15               0  20251231  Uttar Pradesh
# 1005746   221207        1         9               0  20251231  Uttar Pradesh
# 1005747   221313        1         0               0  20251231  Uttar Pradesh
#
# ...

# %%
df_uttarpradesh_dist_level_UP = df_uttarpradesh_cleaned_UP.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()
df_uttarpradesh_dist_level_UP['total_enrollment'] = df_uttarpradesh_dist_level_UP['age_0_5'] + df_uttarpradesh_dist_level_UP['age_5_17'] + df_uttarpradesh_dist_level_UP['age_18_greater']

# %%
df_uttarpradesh_dist_level_UP.shape
# Out:
# (78, 4)

# %%
df_uttarpradesh_dist_level_UP
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Agra              16314     12691             905             29910
# Aligarh           13830     11776             586             26192
# Ambedkar Nagar     3856      4096              50              8002
# Amethi             3890      3251              56              7197
# Amroha             5605      2476              61              8142
# ...                 ...       ...             ...               ...
# Sitapur           16237     13869             748             30854
# Sonbhadra          2998      2023              13              5034
# Sultanpur          5465      5837             132             11434
# Unnao              9838      8943             367             19148
# Varanasi           9479     13404             451             23334
#
# [78 rows x 4 columns]

# %%
df_uttarpradesh_dist_level_UP.sort_values("total_enrollment",ascending=False).reset_index()
# df_uttarpradesh_dist_level_UP.to_excel('uttarpradesh_district_level_enrolment.xlsx')
# Out:
#                 district_clean  age_0_5  age_5_17  age_18_greater  \
# 0                     Bahraich    14674     22360            2304
# 1                      Sitapur    16237     13869             748
# 2                         Agra    16314     12691             905
# 3                     Bareilly    17187     10017             607
# 4                      Aligarh    13830     11776             586
# ..                         ...      ...       ...             ...
# 73                    Hamirpur     2040      1398              27
# 74                      Mahoba     1979      1029              12
# 75                     Bhadohi      265       277               4
# 76  Sant Ravidas Nagar Bhadohi       37        47               0
# 77         Jyotiba Phule Nagar       61        23               0
#
#     total_enrollment
# 0              39338
# 1              30854
# 2              29910
# 3              27811
# 4              26192
# ..               ...
# ...

# %%
df_uttarpradesh_dist_level1 = df_uttarpradesh_dist_level_UP.head(10)
df_uttarpradesh_dist_level1
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Agra              16314     12691             905             29910
# Aligarh           13830     11776             586             26192
# Ambedkar Nagar     3856      4096              50              8002
# Amethi             3890      3251              56              7197
# Amroha             5605      2476              61              8142
# Auraiya            2169      1547              17              3733
# Ayodhya            5079      3505              35              8619
# Azamgarh           6717     13577             279             20573
# Baghpat            3482      3204             154              6840
# Bahraich          14674     22360            2304             39338

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.lineplot(data=df_uttarpradesh_dist_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Districts in uttarpradesh - Age Group Enrollment Comparison')
plt.xlabel('Districts')
plt.ylabel('Number of Enrollments')
plt.legend(title='Age Groups', labels=['Age 0-5', 'Age 5-17', 'Age 18 and above'])
plt.xticks(ticks=range(len(df_uttarpradesh_dist_level1.index)), labels=df_uttarpradesh_dist_level1.index, rotation=45)
plt.show()

# %%
df_uttarpradesh_pincode_level = df_uttarpradesh_cleaned_UP.groupby('pincode')[['age_0_5','age_5_17','age_18_greater']].sum()
df_uttarpradesh_pincode_level['total_enrollment'] = df_uttarpradesh_pincode_level['age_0_5'] + df_uttarpradesh_pincode_level['age_5_17'] + df_uttarpradesh_pincode_level['age_18_greater']
df_uttarpradesh_pincode_level.shape
# Out:
# (1737, 4)

# %%
df_uttarpradesh_pincode_level.sort_values("total_enrollment",ascending=False).reset_index()
# df_uttarpradesh_pincode_level.to_excel('uttarpradesh_pincode_level_enrolment.xlsx')

df_uttarpradesh_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 121705        78       119               0               197
# 201001      2483      1993              73              4549
# 201002       556       548              41              1145
# 201003       161       208               6               375
# 201004         1         2               1                 4
# ...          ...       ...             ...               ...
# 285203       171       209              10               390
# 285204       140       137               0               277
# 285205       428       231              31               690
# 285206        50        39               3                92
# 285223        38        37               0                75
#
# [1737 rows x 4 columns]

# %%
df_uttarpradesh_pincode_level1 = df_uttarpradesh_pincode_level.head(10)
df_uttarpradesh_pincode_level1
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 121705        78       119               0               197
# 201001      2483      1993              73              4549
# 201002       556       548              41              1145
# 201003       161       208               6               375
# 201004         1         2               1                 4
# 201005       769       562              31              1362
# 201006       124        37               4               165
# 201007       156       134               3               293
# 201008        39        25               0                64
# 201009       790       555              35              1380

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=df_uttarpradesh_pincode_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Pincodes in Uttar Pradesh - Age Group Enrollment Comparison')
plt.xlabel('Pincodes')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## monthly enrolment trend in bihar
df_uttarpradesh_monthly = df_uttarpradesh_cleaned_UP.groupby('month')[['age_0_5','age_5_17','age_18_greater']].sum()
df_uttarpradesh_monthly['total_enrollment'] = df_uttarpradesh_monthly['age_0_5'] + df_uttarpradesh_monthly['age_5_17'] + df_uttarpradesh_monthly['age_18_greater']
df_uttarpradesh_monthly.shape
# Out:
# (9, 4)

# %%
df_uttarpradesh_monthly
df_uttarpradesh_monthly.sort_values("total_enrollment",ascending=False).reset_index()
# Out:
#   month  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0    09   126150    132594            2335            261079
# 1    11   100584     79629            2482            182695
# 2    07    73166     81078            3622            157866
# 3    10    70638     65271            2243            138152
# 4    12    68564     46961            1402            116927
# 5    04    32513     23189            2201             57903
# 6    05    26928     21554            1379             49861
# 7    06    21109     26080            1564             48753
# 8    03     1393      3326             674              5393

# %%
sns.lineplot(data=df_uttarpradesh_monthly)
# Out:
# <Axes: xlabel='month'>

# %%
## Stacked bar plot for age group comparison
plt.figure(figsize=(10,6))
df_uttarpradesh_monthly[['age_0_5', 'age_5_17', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Uttar Pradesh Monthly Aadhar Enrollments by Age Group')
plt.xlabel('Month')
plt.ylabel('Number of Enrollments')
plt.show()

# %% [markdown]
# # Madhya Pradesh ke liye

# %%
df_madhyapradesh= df[df['state_clean']=='Madhya Pradesh']
df_madhyapradesh
# Out:
#                date           state    district  pincode  age_0_5  age_5_17  \
# 25       09-03-2025  Madhya Pradesh       Bhind   477116       37        18
# 26       09-03-2025  Madhya Pradesh     Gwalior   475110       42        14
# 27       09-03-2025  Madhya Pradesh       Katni   483501       53        42
# 76       20-03-2025  Madhya Pradesh     Gwalior   474001       73        25
# 125      23-03-2025  Madhya Pradesh     Gwalior   474001       10        21
# ...             ...             ...         ...      ...      ...       ...
# 1004141  31-12-2025  Madhya Pradesh      Umaria   484661       66        23
# 1004142  31-12-2025  Madhya Pradesh      Umaria   486661        2         0
# 1004143  31-12-2025  Madhya Pradesh     Vidisha   464001       32         6
# 1004144  31-12-2025  Madhya Pradesh     Vidisha   464220        7         3
# 1004145  31-12-2025  Madhya Pradesh  West Nimar   451111        2         1
#
# ...

# %%
df_madhyapradesh['district'].unique()
# Out:
# array(['Bhind', 'Gwalior', 'Katni', 'Ashok Nagar', 'Betul', 'Guna',
#        'Khargone', 'Chhatarpur', 'Morena', 'Dhar', 'Jabalpur', 'Barwani',
#        'Shivpuri', 'Raisen', 'Jhabua', 'Indore', 'Bhopal', 'Datia',
#        'Sagar', 'Sheopur', 'Vidisha', 'Burhanpur', 'Panna', 'Khandwa',
#        'Satna', 'Alirajpur', 'Dewas', 'Ashoknagar', 'Balaghat',
#        'East Nimar', 'Sehore', 'Narsinghpur', 'Hoshangabad', 'Agar Malwa',
#        'Anuppur', 'Chhindwara', 'Damoh', 'Dindori', 'Harda', 'Maihar',
#        'Mandla', 'Mandsaur', 'Narmadapuram', 'Narsimhapur', 'Neemuch',
#        'Niwari', 'Rajgarh', 'Ratlam', 'Rewa', 'Seoni', 'Shahdol',
#        'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh', 'Ujjain',
#        'West Nimar', 'Harda *', 'Mauganj', 'Umaria', 'Pandhurna'],
#       dtype=object)

# %%
df_madhyapradesh['district'].nunique()
# Out:
# 61

# %%
df_madhyapradesh['district_clean'] = (
    df_madhyapradesh['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\*', '', regex=True)
    .str.replace(r'\(.*?\)', '', regex=True)
    .str.replace(r'[^a-z\s]', '', regex=True)
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1754192845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_madhyapradesh['district_clean'] = (

# %%
mp_district_standard_map = {
    "ashok nagar": "Ashoknagar",
    "ashoknagar": "Ashoknagar",

    "east nimar": "Khandwa",
    "west nimar": "Khargone",

    "hoshangabad": "Narmadapuram",
    "narmadapuram": "Narmadapuram",

    "narsimhapur": "Narsinghpur",
    "narsinghpur": "Narsinghpur",

    "harda *": "Harda",
    "harda": "Harda",

    "mauganj": "Mauganj",
    "pandhurna": "Pandhurna"
}

# %%
df_madhyapradesh['district_clean'] = (
    df['district']
    .apply(clean_name)
    .map(mp_district_standard_map)
    .fillna(df_madhyapradesh['district'])

)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/2376381053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_madhyapradesh['district_clean'] = (

# %%
## Remaining unmapped
df_madhyapradesh[df_madhyapradesh['district_clean'].isna()]['district'].unique()
# count check 
df_madhyapradesh['district_clean'].nunique()
# Out:
# 57

# %%
df_madhyapradesh.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# new_date          0
# state_clean       0
# district_clean    0
# dtype: int64

# %%
df_madhyapradesh
# Out:
#                date           state    district  pincode  age_0_5  age_5_17  \
# 25       09-03-2025  Madhya Pradesh       Bhind   477116       37        18
# 26       09-03-2025  Madhya Pradesh     Gwalior   475110       42        14
# 27       09-03-2025  Madhya Pradesh       Katni   483501       53        42
# 76       20-03-2025  Madhya Pradesh     Gwalior   474001       73        25
# 125      23-03-2025  Madhya Pradesh     Gwalior   474001       10        21
# ...             ...             ...         ...      ...      ...       ...
# 1004141  31-12-2025  Madhya Pradesh      Umaria   484661       66        23
# 1004142  31-12-2025  Madhya Pradesh      Umaria   486661        2         0
# 1004143  31-12-2025  Madhya Pradesh     Vidisha   464001       32         6
# 1004144  31-12-2025  Madhya Pradesh     Vidisha   464220        7         3
# 1004145  31-12-2025  Madhya Pradesh  West Nimar   451111        2         1
#
# ...

# %%
## total enrolment by district in uttar pradesh
df_madhyapradesh_dist_level = df_madhyapradesh.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()

# %%
df_madhyapradesh['total_enrollment'] = (
    df_madhyapradesh['age_0_5'] +
    df_madhyapradesh['age_5_17'] +
    df_madhyapradesh['age_18_greater']
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/2512688501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_madhyapradesh['total_enrollment'] = (

# %%
df_madhyapradesh
# Out:
#                date           state    district  pincode  age_0_5  age_5_17  \
# 25       09-03-2025  Madhya Pradesh       Bhind   477116       37        18
# 26       09-03-2025  Madhya Pradesh     Gwalior   475110       42        14
# 27       09-03-2025  Madhya Pradesh       Katni   483501       53        42
# 76       20-03-2025  Madhya Pradesh     Gwalior   474001       73        25
# 125      23-03-2025  Madhya Pradesh     Gwalior   474001       10        21
# ...             ...             ...         ...      ...      ...       ...
# 1004141  31-12-2025  Madhya Pradesh      Umaria   484661       66        23
# 1004142  31-12-2025  Madhya Pradesh      Umaria   486661        2         0
# 1004143  31-12-2025  Madhya Pradesh     Vidisha   464001       32         6
# 1004144  31-12-2025  Madhya Pradesh     Vidisha   464220        7         3
# 1004145  31-12-2025  Madhya Pradesh  West Nimar   451111        2         1
#
# ...

# %%
# enrolment top 10 district 
df_MP_district_level =df_madhyapradesh["district_clean"].head(10)

# %%
## total enrolment by district in uttar pradesh
state_summary_MP = df_madhyapradesh.groupby('district_clean')[[
    'age_0_5', 'age_5_17', 'age_18_greater'
]].sum() ## means of all age group by district

state_summary_MP['total_enrollment'] = (
    state_summary_MP['age_0_5'] +
    state_summary_MP['age_5_17'] +
    state_summary_MP['age_18_greater'] ## total enrolment by district
)

top10_districts_MP = state_summary_MP.sort_values(
    by='total_enrollment', ascending=False
).head(10)

# %%
## bar plot for top 10 states
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.barplot(
    x=top10_districts_MP.index,
    y=top10_districts_MP['total_enrollment'],
    palette='viridis'
)
plt.title('Top 10 Districts by Total Aadhar Enrollments in Uttar Pradesh')
plt.xlabel('Districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/4119891440.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top10_districts_MP['children_enrollment'] = (
    top10_districts_MP['age_0_5'] +
    top10_districts_MP['age_5_17']
)

# %%
# Stacked bar plot for age group comparison
plt.figure(figsize=(14,6))
top10_districts_MP[['children_enrollment', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Top 10 districts: Children vs Adults Enrollment')
plt.xlabel('districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_madhyapradesh['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
pincode_check_MP = df_madhyapradesh.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincodes')
pincode_check_MP
# Out:
#    district_clean  unique_pincodes
# 0      Agar Malwa                6
# 1       Alirajpur               10
# 2         Anuppur               20
# 3      Ashoknagar               10
# 4        Balaghat               24
# 5         Barwani               11
# 6           Betul               21
# 7           Bhind               20
# 8          Bhopal               38
# 9       Burhanpur                5
# 10     Chhatarpur               20
# 11     Chhindwara               27
# 12          Damoh               14
# 13          Datia                9
# 14          Dewas               18
# 15           Dhar               23
# 16        Dindori                9
# 17     East Nimar               20
# 18           Guna               20
# 19        Gwalior               21
# 20          Harda                6
# 21         Indore               31
# 22       Jabalpur               27
# 23         Jhabua               14
# 24          Katni               17
# 25        Khandwa               16
# ...

# %%
pin_district_count_MP = (
    df_madhyapradesh.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count_MP
# Out:
#      pincode  district_count
# 0     450001               2
# 1     450051               2
# 2     450110               2
# 3     450112               2
# 4     450114               2
# ..       ...             ...
# 782   488441               1
# 783   488442               1
# 784   488443               1
# 785   488446               1
# 786   488448               1
#
# [787 rows x 2 columns]

# %%
problem_pins_MP = pin_district_count_MP[
    pin_district_count_MP['district_count'] > 1
]

# %%
problem_pins_MP
## ek pin code 2 district se belong kr skta hai theek ye govt ki website pr hai
# Out:
#      pincode  district_count
# 0     450001               2
# 1     450051               2
# 2     450110               2
# 3     450112               2
# 4     450114               2
# ..       ...             ...
# 748   486882               2
# 749   486884               2
# 751   486886               4
# 754   486889               2
# 755   486890               2
#
# [163 rows x 2 columns]

# %%
df_flagged_MP = df_madhyapradesh.merge(
    problem_pins_MP[['pincode']],
    on='pincode',
    how='inner'
)

# %%
## ye sab o hai jissme ek district ke 2 pincode hai
## yha se hum pta kr skte hai kiss district me jda use ho rha hai 
df_flagged_MP
# Out:
#              date           state     district  pincode  age_0_5  age_5_17  \
# 0      09-03-2025  Madhya Pradesh      Gwalior   475110       42        14
# 1      27-03-2025  Madhya Pradesh      Gwalior   475110       54        26
# 2      01-04-2025  Madhya Pradesh  Ashok Nagar   473335      125        29
# 3      01-04-2025  Madhya Pradesh  Ashok Nagar   473443      141        57
# 4      01-04-2025  Madhya Pradesh         Guna   473101      110        32
# ...           ...             ...          ...      ...      ...       ...
# 13797  31-12-2025  Madhya Pradesh    Tikamgarh   472246        6         5
# 13798  31-12-2025  Madhya Pradesh       Umaria   484661       66        23
# 13799  31-12-2025  Madhya Pradesh       Umaria   486661        2         0
# 13800  31-12-2025  Madhya Pradesh      Vidisha   464001       32         6
# 13801  31-12-2025  Madhya Pradesh   West Nimar   451111        2         1
#
#        age_18_greater  new_date     state_clean district_clean  \
# ...

# %%
flagged_pincode_MP=df_flagged_MP.groupby(['district_clean','pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()
#flagged_pincode_MP.to_excel('flagged_pincode_domain.xlsx')

# %%
flagged_pincode_MP['total_enrollment']=flagged_pincode_MP['age_0_5']+flagged_pincode_MP['age_5_17']+flagged_pincode_MP['age_18_greater']
flagged_pincode_MP
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 0       Agar Malwa   465230      257        56               3
# 1       Agar Malwa   465441      618       136              16
# 2       Agar Malwa   465445      371        66               0
# 3       Agar Malwa   465447      389        81               2
# 4       Agar Malwa   465550      205        47               7
# ..             ...      ...      ...       ...             ...
# 345     West Nimar   451335       18         8               0
# 346     West Nimar   451440       45         6               0
# 347     West Nimar   451441       76        33               0
# 348     West Nimar   451442       27         9               1
# 349     West Nimar   451660       13         1               0
#
#      total_enrollment
# 0                 316
# 1                 770
# 2                 437
# 3                 472
# 4                 259
# ..                ...
# 345                26
# ...

# %%
idx = flagged_pincode_MP.groupby('pincode')['total_enrollment'].idxmax()
df_filtered_MP = flagged_pincode_MP.loc[idx]
df_filtered_MP
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 141        Khandwa   450001     1091       302              17
# 142        Khandwa   450051       47        17               1
# 143        Khandwa   450110       54        23               0
# 144        Khandwa   450112      107        61               5
# 84      East Nimar   450114      144       103               2
# ..             ...      ...      ...       ...             ...
# 303      Singrauli   486882     1006       131               5
# 297          Sidhi   486884       47         6               0
# 305      Singrauli   486886     2250       364               3
# 306      Singrauli   486889      228        69               7
# 300          Sidhi   486890       69        24               0
#
#      total_enrollment
# 141              1410
# 142                65
# 143                77
# 144               173
# 84                249
# ..                ...
# 303              1142
# ...

# %%
df_madhyapradesh['pin_multi_district_flag']=(
    df_madhyapradesh.groupby('pincode')['district_clean']
    .transform('nunique')>1
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1963035757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_madhyapradesh['pin_multi_district_flag']=(

# %%
pin_district_map_MP = (
    df_madhyapradesh[df_madhyapradesh['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']  # noqa: SC100
    .unique()
    .reset_index()
)

# %%
## monthly enrolment check 
df_madhyapradesh['month'] = df_madhyapradesh['new_date'].astype(str).str[4:6]
df_madhyapradesh
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1113108687.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_madhyapradesh['month'] = df_madhyapradesh['new_date'].astype(str).str[4:6]
#                date           state    district  pincode  age_0_5  age_5_17  \
# 25       09-03-2025  Madhya Pradesh       Bhind   477116       37        18
# 26       09-03-2025  Madhya Pradesh     Gwalior   475110       42        14
# 27       09-03-2025  Madhya Pradesh       Katni   483501       53        42
# 76       20-03-2025  Madhya Pradesh     Gwalior   474001       73        25
# 125      23-03-2025  Madhya Pradesh     Gwalior   474001       10        21
# ...

# %%
df_madhyapradesh_cleaned_MP=df_madhyapradesh.drop(columns=['date','district','state'], axis=1)
df_madhyapradesh_cleaned_MP
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date     state_clean  \
# 25        477116       37        18              11  20250309  Madhya Pradesh
# 26        475110       42        14              14  20250309  Madhya Pradesh
# 27        483501       53        42              11  20250309  Madhya Pradesh
# 76        474001       73        25              18  20250320  Madhya Pradesh
# 125       474001       10        21              16  20250323  Madhya Pradesh
# ...          ...      ...       ...             ...       ...             ...
# 1004141   484661       66        23               0  20251231  Madhya Pradesh
# 1004142   486661        2         0               0  20251231  Madhya Pradesh
# 1004143   464001       32         6               0  20251231  Madhya Pradesh
# 1004144   464220        7         3               0  20251231  Madhya Pradesh
# 1004145   451111        2         1               0  20251231  Madhya Pradesh
#
# ...

# %%
df_madhyapradesh_dist_level_MP = df_madhyapradesh_cleaned_MP.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()
df_madhyapradesh_dist_level_MP['total_enrollment'] = df_madhyapradesh_dist_level_MP['age_0_5'] + df_madhyapradesh_dist_level_MP['age_5_17'] + df_madhyapradesh_dist_level_MP['age_18_greater']

# %%
df_madhyapradesh_dist_level_MP.shape
# Out:
# (57, 4)

# %%
df_madhyapradesh_dist_level_MP
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Agar Malwa         2087       421              29              2537
# Alirajpur          3251      3390             369              7010
# Anuppur            2864       349              13              3226
# Ashoknagar         5320      2608             261              8189
# Balaghat           6237       540              28              6805
# Barwani           12801      8355             667             21823
# Betul              6829      1207             130              8166
# Bhind              8483      4845             639             13967
# Bhopal            11256      1452             154             12862
# Burhanpur          6542      2759             388              9689
# Chhatarpur        11504      5965             367             17836
# Chhindwara         8308       625              48              8981
# Damoh              5081       938              47              6066
# ...

# %%
df_madhyapradesh_dist_level_MP.sort_values("total_enrollment",ascending=False).reset_index()
# df_madhyapradesh_dist_level_MP.to_excel('madhyapradesh_district_level_enrolment.xlsx')
# Out:
#    district_clean  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0          Morena    14064      7647             670             22381
# 1          Indore    16685      5009             609             22303
# 2         Barwani    12801      8355             667             21823
# 3         Gwalior    12110      5602             830             18542
# 4      Chhatarpur    11504      5965             367             17836
# 5        Khargone     9870      4663             506             15039
# 6          Ujjain    12450      1763              95             14308
# 7           Bhind     8483      4845             639             13967
# 8           Sagar    11572      1882             387             13841
# 9          Jhabua     6586      6570             332             13488
# 10          Satna    11198      1946             132             13276
# 11         Bhopal    11256      1452             154             12862
# ...

# %%
df_madhyapradesh_dist_level1 = df_madhyapradesh_dist_level_MP.head(10)
df_madhyapradesh_dist_level1
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Agar Malwa         2087       421              29              2537
# Alirajpur          3251      3390             369              7010
# Anuppur            2864       349              13              3226
# Ashoknagar         5320      2608             261              8189
# Balaghat           6237       540              28              6805
# Barwani           12801      8355             667             21823
# Betul              6829      1207             130              8166
# Bhind              8483      4845             639             13967
# Bhopal            11256      1452             154             12862
# Burhanpur          6542      2759             388              9689

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.lineplot(data=df_madhyapradesh_dist_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Districts in madhyapradesh - Age Group Enrollment Comparison')
plt.xlabel('Districts')
plt.ylabel('Number of Enrollments')
plt.legend(title='Age Groups', labels=['Age 0-5', 'Age 5-17', 'Age 18 and above'])
plt.xticks(ticks=range(len(df_madhyapradesh_dist_level1.index)), labels=df_madhyapradesh_dist_level1.index, rotation=45)
plt.show()

# %%
df_madhyapradesh_pincode_level = df_madhyapradesh_cleaned_MP.groupby('pincode')[['age_0_5','age_5_17','age_18_greater']].sum()
df_madhyapradesh_pincode_level['total_enrollment'] = df_madhyapradesh_pincode_level['age_0_5'] + df_madhyapradesh_pincode_level['age_5_17'] + df_madhyapradesh_pincode_level['age_18_greater']
df_madhyapradesh_pincode_level.shape
# Out:
# (787, 4)

# %%
df_madhyapradesh_pincode_level.sort_values("total_enrollment",ascending=False).reset_index()
# df_madhyapradesh_pincode_level.to_excel('madhyapradesh_pincode_level_enrolment.xlsx')

df_madhyapradesh_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 450001      1535       420              17              1972
# 450051        76        44               1               121
# 450110        77        33               0               110
# 450112       194       113               6               313
# 450114       224       155               2               381
# ...          ...       ...             ...               ...
# 488441       763       222              21              1006
# 488442       903       280               8              1191
# 488443         5         0               0                 5
# 488446       734       256               3               993
# 488448       485       130               4               619
#
# [787 rows x 4 columns]

# %%
df_madhyapradesh_pincode_level1 = df_madhyapradesh_pincode_level.head(10)
df_madhyapradesh_pincode_level1
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 450001      1535       420              17              1972
# 450051        76        44               1               121
# 450110        77        33               0               110
# 450112       194       113               6               313
# 450114       224       155               2               381
# 450116       450       219               0               669
# 450117      1086       656              17              1759
# 450119        16         5               0                21
# 450221       879       372             130              1381
# 450331      4234      1625             207              6066

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=df_madhyapradesh_pincode_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Pincodes in Madhya Pradesh - Age Group Enrollment Comparison')
plt.xlabel('Pincodes')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## monthly enrolment trend in bihar
df_madhyapradesh_monthly = df_madhyapradesh_cleaned_MP.groupby('month')[['age_0_5','age_5_17','age_18_greater']].sum()
df_madhyapradesh_monthly['total_enrollment'] = df_madhyapradesh_monthly['age_0_5'] + df_madhyapradesh_monthly['age_5_17'] + df_madhyapradesh_monthly['age_18_greater']
df_madhyapradesh_monthly.shape
# Out:
# (9, 4)

# %%
df_madhyapradesh_monthly
df_madhyapradesh_monthly.sort_values("total_enrollment",ascending=False).reset_index()
# Out:
#   month  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0    09    98016     33562             939            132517
# 1    11    84762     16930            1847            103539
# 2    12    70570     12807            1074             84451
# 3    10    50371     11943            1311             63625
# 4    07    34979     26040            2169             63188
# 5    06     9708      7774             672             18154
# 6    04    12077      4146            1128             17351
# 7    05     7221      3018             364             10603
# 8    03      286       161              95               542

# %%
sns.lineplot(data=df_madhyapradesh_monthly)
# Out:
# <Axes: xlabel='month'>

# %%
## Stacked bar plot for age group comparison
plt.figure(figsize=(10,6))
df_madhyapradesh_monthly[['age_0_5', 'age_5_17', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Madhya Pradesh Monthly Aadhar Enrollments by Age Group')
plt.xlabel('Month')
plt.ylabel('Number of Enrollments')
plt.show()

# %% [markdown]
# # West Bengal

# %%
df_West_Bengal= df[df['state_clean']=='West Bengal']
df_West_Bengal
# Out:
#                date        state           district  pincode  age_0_5  \
# 30       09-03-2025  West Bengal         Coochbehar   736135       19
# 32       09-03-2025  West Bengal     Dinajpur Uttar   733129       26
# 173      01-04-2025  West Bengal         Darjeeling   734010       81
# 199      01-04-2025  West Bengal        Cooch Behar   736135      243
# 208      01-04-2025  West Bengal  North 24 Parganas   700159       35
# ...             ...          ...                ...      ...      ...
# 1006024  31-12-2025  West Bengal     West Midnapore   721149        2
# 1006025  31-12-2025  West Bengal     West Midnapore   721150        2
# 1006026  31-12-2025  West Bengal     West Midnapore   721305        0
# 1006027  31-12-2025  West Bengal     West Midnapore   721504        1
# 1006028  31-12-2025  West Bengal     West Midnapore   721517        2
#
#          age_5_17  age_18_greater  new_date  state_clean district_clean
# ...

# %%
df_West_Bengal['district'].unique()
# Out:
# array(['Coochbehar', 'Dinajpur Uttar', 'Darjeeling', 'Cooch Behar',
#        'North 24 Parganas', 'Uttar Dinajpur', 'Jhargram', 'Nadia',
#        'Jalpaiguri', 'Alipurduar', 'Malda', 'Kolkata', 'Dakshin Dinajpur',
#        'Kalimpong', 'Birbhum', '24 Paraganas North', 'Medinipur West',
#        'Purba Bardhaman', 'Hooghly', '24 Paraganas South', 'Howrah',
#        'Dinajpur Dakshin', 'Bankura', 'Barddhaman', 'Bardhaman',
#        'Darjiling', 'East Midnapore', 'Haora', 'Koch Bihar', 'Maldah',
#        'Murshidabad', 'North Twenty Four Parganas', 'Paschim Bardhaman',
#        'Paschim Medinipur', 'Purba Medinipur', 'Purulia', 'Puruliya',
#        'South 24 Parganas', 'South Dinajpur',
#        'South Twenty Four Parganas', 'West Midnapore', 'Hugli',
#        'North Dinajpur', 'HOOGHLY', 'NADIA', 'HOWRAH', 'Hawrah', 'MALDA',
#        'hooghly', 'Medinipur', 'East Midnapur', 'nadia', 'Hooghiy',
#        'KOLKATA', 'West Medinipur', 'Burdwan', 'South 24 parganas',
# ...

# %%
df_West_Bengal['district'].nunique()
# Out:
# 58

# %%
df_West_Bengal['district_clean'] = (
    df_West_Bengal['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\*', '', regex=True)
    .str.replace(r'\(.*?\)', '', regex=True)
    .str.replace(r'[^a-z\s]', '', regex=True)
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/2946288043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_West_Bengal['district_clean'] = (

# %%
wb_district_standard_map = {
    "coochbehar": "Cooch Behar",
    "cooch behar": "Cooch Behar",
    "koch bihar": "Cooch Behar",

    "dinajpur uttar": "Uttar Dinajpur",
    "uttar dinajpur": "Uttar Dinajpur",
    "north dinajpur": "Uttar Dinajpur",

    "dinajpur dakshin": "Dakshin Dinajpur",
    "dakshin dinajpur": "Dakshin Dinajpur",
    "south dinajpur": "Dakshin Dinajpur",

    "darjeeling": "Darjeeling",
    "darjiling": "Darjeeling",

    "kalimpong": "Kalimpong",

    "north 24 parganas": "North 24 Parganas",
    "24 paraganas north": "North 24 Parganas",
    "north twenty four parganas": "North 24 Parganas",

    "south 24 parganas": "South 24 Parganas",
    "south 24 pargana": "South 24 Parganas",
    "south 24 parganas": "South 24 Parganas",
    "24 paraganas south": "South 24 Parganas",
    "south twenty four parganas": "South 24 Parganas",

    "nadia": "Nadia",

    "jalpaiguri": "Jalpaiguri",
    "alipurduar": "Alipurduar",

    "malda": "Malda",
    "maldah": "Malda",

    "kolkata": "Kolkata",

    "jhargram": "Jhargram",
    "birbhum": "Birbhum",

    "medinipur west": "Paschim Medinipur",
    "west medinipur": "Paschim Medinipur",
    "west midnapore": "Paschim Medinipur",
    "paschim medinipur": "Paschim Medinipur",
    "medinipur": "Paschim Medinipur",

    "purba medinipur": "Purba Medinipur",
    "east midnapore": "Purba Medinipur",
    "east midnapur": "Purba Medinipur",

    "barddhaman": "Bardhaman",
    "bardhaman": "Bardhaman",
    "burdwan": "Bardhaman",

    "purba bardhaman": "Purba Bardhaman",
    "paschim bardhaman": "Paschim Bardhaman",

    "hooghly": "Hooghly",
    "hugli": "Hooghly",
    "hooghiy": "Hooghly",

    "howrah": "Howrah",
    "haora": "Howrah",
    "hawrah": "Howrah",

    "murshidabad": "Murshidabad",
    "bankura": "Bankura",

    "purulia": "Purulia",
    "puruliya": "Purulia"
}

# %%
df_West_Bengal['district_clean'] = (
    df['district']
    .apply(clean_name)
    .map(wb_district_standard_map)
    .fillna(df_West_Bengal['district'])

)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3916602445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_West_Bengal['district_clean'] = (

# %%
## Remaining unmapped
df_West_Bengal[df_West_Bengal['district_clean'].isna()]['district'].unique()
# count check 
df_West_Bengal['district_clean'].nunique()
# Out:
# 40

# %%
df_West_Bengal.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# new_date          0
# state_clean       0
# district_clean    0
# dtype: int64

# %%
df_West_Bengal
# Out:
#                date        state           district  pincode  age_0_5  \
# 30       09-03-2025  West Bengal         Coochbehar   736135       19
# 32       09-03-2025  West Bengal     Dinajpur Uttar   733129       26
# 173      01-04-2025  West Bengal         Darjeeling   734010       81
# 199      01-04-2025  West Bengal        Cooch Behar   736135      243
# 208      01-04-2025  West Bengal  North 24 Parganas   700159       35
# ...             ...          ...                ...      ...      ...
# 1006024  31-12-2025  West Bengal     West Midnapore   721149        2
# 1006025  31-12-2025  West Bengal     West Midnapore   721150        2
# 1006026  31-12-2025  West Bengal     West Midnapore   721305        0
# 1006027  31-12-2025  West Bengal     West Midnapore   721504        1
# 1006028  31-12-2025  West Bengal     West Midnapore   721517        2
#
#          age_5_17  age_18_greater  new_date  state_clean     district_clean
# ...

# %%
# total enrolment by district in uttar pradesh
df_West_Bengal_dist_level = df_West_Bengal.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()

# %%
df_West_Bengal['total_enrollment'] = (
    df_West_Bengal['age_0_5'] +
    df_West_Bengal['age_5_17'] +
    df_West_Bengal['age_18_greater']
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1577518966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_West_Bengal['total_enrollment'] = (

# %%
df_West_Bengal
# Out:
#                date        state           district  pincode  age_0_5  \
# 30       09-03-2025  West Bengal         Coochbehar   736135       19
# 32       09-03-2025  West Bengal     Dinajpur Uttar   733129       26
# 173      01-04-2025  West Bengal         Darjeeling   734010       81
# 199      01-04-2025  West Bengal        Cooch Behar   736135      243
# 208      01-04-2025  West Bengal  North 24 Parganas   700159       35
# ...             ...          ...                ...      ...      ...
# 1006024  31-12-2025  West Bengal     West Midnapore   721149        2
# 1006025  31-12-2025  West Bengal     West Midnapore   721150        2
# 1006026  31-12-2025  West Bengal     West Midnapore   721305        0
# 1006027  31-12-2025  West Bengal     West Midnapore   721504        1
# 1006028  31-12-2025  West Bengal     West Midnapore   721517        2
#
#          age_5_17  age_18_greater  new_date  state_clean     district_clean  \
# ...

# %%
# enrolment top 10 district 
df_West_Bengal_level = df_West_Bengal["district_clean"].head(10)

# %%
## total enrolment by district in uttar pradesh
state_summary_wb = df_West_Bengal.groupby('district_clean')[[
    'age_0_5', 'age_5_17', 'age_18_greater'
]].sum() ## means of all age group by district

state_summary_wb['total_enrollment'] = (
    state_summary_wb['age_0_5'] +
    state_summary_wb['age_5_17'] +
    state_summary_wb['age_18_greater'] ## total enrolment by district
)

top10_districts_wb = state_summary_wb.sort_values(
    by='total_enrollment', ascending=False
).head(10)

# %%
## bar plot for top 10 states
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.barplot(
    x=top10_districts_wb.index,
    y=top10_districts_wb['total_enrollment'],
    palette='viridis'
)
plt.title('Top 10 Districts by Total Aadhar Enrollments in West Bengal')
plt.xlabel('Districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1106510956.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top10_districts_wb['children_enrollment'] = (
    top10_districts_wb['age_0_5'] +
    top10_districts_wb['age_5_17']
)

# %%
# Stacked bar plot for age group comparison
plt.figure(figsize=(14,6))
top10_districts_wb[['children_enrollment', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Top 10 districts: Children vs Adults Enrollment')
plt.xlabel('districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_West_Bengal['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
pincode_check_wb = df_West_Bengal.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincodes')
pincode_check_wb
# Out:
#                 district_clean  unique_pincodes
# 0           24 Paraganas North               23
# 1           24 Paraganas South                1
# 2                   Alipurduar               25
# 3                      Bankura               74
# 4                    Bardhaman              167
# 5                      Birbhum               49
# 6                  Cooch Behar               45
# 7             Dakshin Dinajpur               27
# 8                   Darjeeling               64
# 9             Dinajpur Dakshin                2
# 10              Dinajpur Uttar                6
# 11              East Midnapore               77
# 12               East Midnapur                1
# 13                     Hooghly              106
# 14                      Howrah               59
# 15                  Jalpaiguri               71
# 16                    Jhargram               46
# 17                   Kalimpong               17
# 18                  Koch Bihar               39
# ...

# %%
pin_district_count_wb = (
    df_West_Bengal.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count_wb
# Out:
#       pincode  district_count
# 0      700001               1
# 1      700002               1
# 2      700003               1
# 3      700004               1
# 4      700005               1
# ...       ...             ...
# 1331   743702               1
# 1332   743704               2
# 1333   743710               2
# 1334   743711               3
# 1335   756084               1
#
# [1336 rows x 2 columns]

# %%
problem_pins_wb = pin_district_count_wb[
    pin_district_count_wb['district_count'] > 1
]

# %%
problem_pins_wb
## ek pin code 2 district se belong kr skta hai theek ye govt ki website pr hai
# Out:
#       pincode  district_count
# 7      700008               3
# 17     700018               2
# 23     700024               2
# 27     700028               2
# 29     700030               3
# ...       ...             ...
# 1328   743613               2
# 1330   743701               2
# 1332   743704               2
# 1333   743710               2
# 1334   743711               3
#
# [634 rows x 2 columns]

# %%
df_flagged_wb = df_West_Bengal.merge(
    problem_pins_wb[['pincode']],
    on='pincode',
    how='inner'
)

# %%
## ye sab o hai jissme ek district ke 2 pincode hai
## yha se hum pta kr skte hai kiss district me jda use ho rha hai 
df_flagged_wb
# Out:
#              date        state           district  pincode  age_0_5  age_5_17  \
# 0      09-03-2025  West Bengal         Coochbehar   736135       19        12
# 1      09-03-2025  West Bengal     Dinajpur Uttar   733129       26        18
# 2      01-04-2025  West Bengal        Cooch Behar   736135      243       127
# 3      01-04-2025  West Bengal  North 24 Parganas   700159       35        28
# 4      01-04-2025  West Bengal     Uttar Dinajpur   733134      484       109
# ...           ...          ...                ...      ...      ...       ...
# 44684  31-12-2025  West Bengal     West Midnapore   721149        2         0
# 44685  31-12-2025  West Bengal     West Midnapore   721150        2         2
# 44686  31-12-2025  West Bengal     West Midnapore   721305        0         1
# 44687  31-12-2025  West Bengal     West Midnapore   721504        1         0
# 44688  31-12-2025  West Bengal     West Midnapore   721517        2         1
#
# ...

# %%
flagged_pincode_wb=df_flagged_wb.groupby(['district_clean','pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()
#flagged_pincode.to_excel('flagged_pincode_domain.xlsx')

# %%
flagged_pincode_wb['total_enrollment']=flagged_pincode_wb['age_0_5']+flagged_pincode_wb['age_5_17']+flagged_pincode_wb['age_18_greater']
flagged_pincode_wb
# Out:
#           district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 0     24 Paraganas North   700049       55        67              12
# 1     24 Paraganas North   700056       34        53              11
# 2     24 Paraganas North   700102       76        67              14
# 3     24 Paraganas North   700110      114       127              25
# 4     24 Paraganas North   700119      116       132              13
# ...                  ...      ...      ...       ...             ...
# 1445      West Midnapore   721513       20         8               1
# 1446      West Midnapore   721515        1         0               0
# 1447      West Midnapore   721516        3         0               0
# 1448      West Midnapore   721517       52        11               0
# 1449      West Midnapore   721641        3         0               0
#
#       total_enrollment
# 0                  134
# 1                   98
# 2                  157
# 3                  266
# ...

# %%
idx = flagged_pincode_wb.groupby('pincode')['total_enrollment'].idxmax()
df_filtered_wb = flagged_pincode_wb.loc[idx]
df_filtered_wb
# Out:
#          district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 1211  South 24 Parganas   700008       30        29               0
# 573             Kolkata   700018      174       263               9
# 574             Kolkata   700024      303       289               9
# 639   North 24 Parganas   700028       86        38               7
# 640   North 24 Parganas   700030       22        21               2
# ...                 ...      ...      ...       ...             ...
# 1286  South 24 Parganas   743613       37        13               0
# 753   North 24 Parganas   743701      100        15               2
# 754   North 24 Parganas   743704      183        40              12
# 755   North 24 Parganas   743710      192        36              14
# 756   North 24 Parganas   743711      298        53               3
#
#       total_enrollment
# 1211                59
# 573                446
# 574                601
# 639                131
# 640                 45
# ...

# %%
df_West_Bengal['pin_multi_district_flag']=(
    df_West_Bengal.groupby('pincode')['district_clean']
    .transform('nunique')>1
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3703270715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_West_Bengal['pin_multi_district_flag']=(

# %%
pin_district_map_wb = (
    df_West_Bengal[df_West_Bengal['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']  # noqa: SC100
    .unique()
    .reset_index()
)

# %%
## monthly enrolment check 
df_West_Bengal['month'] = df_West_Bengal['new_date'].astype(str).str[4:6]
df_West_Bengal
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3600340522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_West_Bengal['month'] = df_West_Bengal['new_date'].astype(str).str[4:6]
#                date        state           district  pincode  age_0_5  \
# 30       09-03-2025  West Bengal         Coochbehar   736135       19
# 32       09-03-2025  West Bengal     Dinajpur Uttar   733129       26
# 173      01-04-2025  West Bengal         Darjeeling   734010       81
# 199      01-04-2025  West Bengal        Cooch Behar   736135      243
# 208      01-04-2025  West Bengal  North 24 Parganas   700159       35
# ...             ...          ...                ...      ...      ...
# ...

# %%
West_Bengal_cleaned_wb=df_West_Bengal.drop(columns=['date','district','state'], axis=1)
West_Bengal_cleaned_wb
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date  state_clean  \
# 30        736135       19        12              19  20250309  West Bengal
# 32        733129       26        18              27  20250309  West Bengal
# 173       734010       81        49              17  20250401  West Bengal
# 199       736135      243       127              20  20250401  West Bengal
# 208       700159       35        28              14  20250401  West Bengal
# ...          ...      ...       ...             ...       ...          ...
# 1006024   721149        2         0               0  20251231  West Bengal
# 1006025   721150        2         2               0  20251231  West Bengal
# 1006026   721305        0         1               0  20251231  West Bengal
# 1006027   721504        1         0               0  20251231  West Bengal
# 1006028   721517        2         1               0  20251231  West Bengal
#
# ...

# %%
West_Bengal_dist_level_wb = West_Bengal_cleaned_wb.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()
West_Bengal_dist_level_wb['total_enrollment'] = West_Bengal_dist_level_wb['age_0_5'] + West_Bengal_dist_level_wb['age_5_17'] + West_Bengal_dist_level_wb['age_18_greater']

# %%
West_Bengal_dist_level_wb.shape
# Out:
# (40, 4)

# %%
West_Bengal_dist_level_wb
# Out:
#                             age_0_5  age_5_17  age_18_greater  \
# district_clean
# 24 Paraganas North             3177      2458             512
# 24 Paraganas South              364       104              22
# Alipurduar                     1521      1714             438
# Bankura                        9083      2122             150
# Bardhaman                     14163      3434              17
# Birbhum                       13361      2041             107
# Cooch Behar                    9402      5307             429
# Dakshin Dinajpur               5358      1069              99
# Darjeeling                     4502      2768             775
# Dinajpur Dakshin                707       256              34
# Dinajpur Uttar                 6478      4859             334
# East Midnapore                 1796       318               4
# East Midnapur                     1         0               0
# Hooghly                       11312      3912             342
# ...

# %%
West_Bengal_dist_level_wb.sort_values("total_enrollment",ascending=False).reset_index()
# West_Bengal_dist_level_wb.to_excel('west_bengal_district_level_enrolment.xlsx')
# Out:
#                 district_clean  age_0_5  age_5_17  age_18_greater  \
# 0                  Murshidabad    31442      4383              86
# 1            South 24 Parganas    25039      8197             304
# 2            North 24 Parganas    21517      5741            1348
# 3               Uttar Dinajpur    18397      8127             368
# 4            Paschim Medinipur    14266      3698             150
# 5                        Nadia    13249      3624             843
# 6                    Bardhaman    14163      3434              17
# 7                        Malda    12979      4523              84
# 8                      Hooghly    11312      3912             342
# 9                      Birbhum    13361      2041             107
# 10                 Cooch Behar     9402      5307             429
# 11             Purba Medinipur    12954      1310              58
# 12                      Howrah    10087      4047             148
# ...

# %%
West_Bengal_dist_level_wb = West_Bengal_dist_level_wb.head(10)
West_Bengal_dist_level_wb
# Out:
#                     age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# 24 Paraganas North     3177      2458             512              6147
# 24 Paraganas South      364       104              22               490
# Alipurduar             1521      1714             438              3673
# Bankura                9083      2122             150             11355
# Bardhaman             14163      3434              17             17614
# Birbhum               13361      2041             107             15509
# Cooch Behar            9402      5307             429             15138
# Dakshin Dinajpur       5358      1069              99              6526
# Darjeeling             4502      2768             775              8045
# Dinajpur Dakshin        707       256              34               997

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.lineplot(data=West_Bengal_dist_level_wb[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Districts in West Bengal - Age Group Enrollment Comparison')
plt.xlabel('Districts')
plt.ylabel('Number of Enrollments')
plt.legend(title='Age Groups', labels=['Age 0-5', 'Age 5-17', 'Age 18 and above'])
plt.xticks(ticks=range(len(West_Bengal_dist_level_wb.index)), labels=West_Bengal_dist_level_wb.index, rotation=45)
plt.show()

# %%
West_Bengal_pincode_level = West_Bengal_cleaned_wb.groupby('pincode')[['age_0_5','age_5_17','age_18_greater']].sum()
West_Bengal_pincode_level['total_enrollment'] = West_Bengal_pincode_level['age_0_5'] + West_Bengal_pincode_level['age_5_17'] + West_Bengal_pincode_level['age_18_greater']
West_Bengal_pincode_level.shape
# Out:
# (1336, 4)

# %%
West_Bengal_pincode_level.sort_values("total_enrollment",ascending=False).reset_index()
# West_Bengal_pincode_level.to_excel('west_bengal_pincode_level_enrolment.xlsx')

West_Bengal_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 700001        10        18               0                28
# 700002       126        74               6               206
# 700003        18        13               3                34
# 700004        99        81             173               353
# 700005        29        16               2                47
# ...          ...       ...             ...               ...
# 743702        74        20               1                95
# 743704       184        40              12               236
# 743710       193        36              14               243
# 743711       342        73               3               418
# 756084         2         2               1                 5
#
# [1336 rows x 4 columns]

# %%
West_Bengal_pincode_level_wb = West_Bengal_pincode_level.head(10)
West_Bengal_pincode_level_wb
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 700001        10        18               0                28
# 700002       126        74               6               206
# 700003        18        13               3                34
# 700004        99        81             173               353
# 700005        29        16               2                47
# 700006       234       248              71               553
# 700007       116       132              19               267
# 700008        56        47               2               105
# 700009        93        89               2               184
# 700010        34        38               6                78

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=West_Bengal_pincode_level_wb[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Pincodes in West Bengal - Age Group Enrollment Comparison')
plt.xlabel('Pincodes')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## monthly enrolment trend in west bengal
West_Bengal_monthly =West_Bengal_cleaned_wb.groupby('month')[['age_0_5','age_5_17','age_18_greater']].sum()
West_Bengal_monthly['total_enrollment'] = West_Bengal_monthly['age_0_5'] + West_Bengal_monthly['age_5_17'] + West_Bengal_monthly['age_18_greater']
West_Bengal_monthly.shape
# Out:
# (9, 4)

# %%
West_Bengal_monthly
West_Bengal_monthly.sort_values("total_enrollment",ascending=False).reset_index()
# Out:
#   month  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0    09    91195     27328            1134            119657
# 1    11    61020     17967             249             79236
# 2    10    60423     17270             199             77892
# 3    12    35858      9321            3590             48769
# 4    07    15274     11657            1613             28544
# 5    05     5538      3500             544              9582
# 6    06     3194      3323             754              7271
# 7    04     2873      1014             381              4268
# 8    03       45        30              46               121

# %%
sns.lineplot(data=West_Bengal_monthly)
# Out:
# <Axes: xlabel='month'>

# %%
## Stacked bar plot for age group comparison
plt.figure(figsize=(10,6))
West_Bengal_monthly[['age_0_5', 'age_5_17', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('West Bengal Monthly Aadhar Enrollments by Age Group')
plt.xlabel('Month')
plt.ylabel('Number of Enrollments')
plt.show()

# %% [markdown]
# # Maharashtra ke liye

# %%
df_Maharashtra= df[df['state_clean']=='Maharashtra']
df_Maharashtra
# Out:
#                date        state    district  pincode  age_0_5  age_5_17  \
# 12       09-03-2025  Maharashtra  Aurangabad   431001       42        46
# 43       15-03-2025  Maharashtra    Parbhani   431401       17        14
# 67       20-03-2025  Maharashtra       Thane   421503       19        13
# 78       20-03-2025  Maharashtra  Aurangabad   431001      134        38
# 151      27-03-2025  Maharashtra  Aurangabad   431001       20        19
# ...             ...          ...         ...      ...      ...       ...
# 1004434  31-12-2025  Maharashtra    Yavatmal   445105        2         1
# 1004435  31-12-2025  Maharashtra    Yavatmal   445109        6         1
# 1004436  31-12-2025  Maharashtra    Yavatmal   445205        4         2
# 1004437  31-12-2025  Maharashtra    Yavatmal   445211        1         0
# 1004438  31-12-2025  Maharashtra    Yavatmal   445401        2         1
#
#          age_18_greater  new_date  state_clean district_clean
# ...

# %%
df_Maharashtra['district'].unique()
# Out:
# array(['Aurangabad', 'Parbhani', 'Thane', 'Nanded', 'Nagpur', 'Jalgaon',
#        'Hingoli', 'Ahmadnagar', 'Palghar', 'Satara', 'Raigad',
#        'Mumbai Suburban', 'Nandurbar', 'Beed', 'Chandrapur', 'Solapur',
#        'Pune', 'Latur', 'Nashik', 'Yavatmal', 'Dhule', 'Washim', 'Sangli',
#        'Buldhana', 'Amravati', 'Ahmednagar', 'Mumbai', 'Akola',
#        'Osmanabad', 'Ahmed Nagar', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Jalna',
#        'Kolhapur', 'Mumbai City', 'Raigarh', 'Ratnagiri', 'Sindhudurg',
#        'Wardha', 'Chatrapati Sambhaji Nagar', 'Mumbai( Sub Urban )',
#        'Nandurbar *', 'Bid', 'Gondiya *', 'Dharashiv', 'Gondia',
#        'Washim *', 'Raigarh(MH)', 'Hingoli *', 'Ahilyanagar'],
#       dtype=object)

# %%
df_Maharashtra['district'].nunique()
# Out:
# 53

# %%
df_Maharashtra['district_clean'] = (
    df_Maharashtra['district']
    .str.lower()
    .str.strip()
    .str.replace(r'\*', '', regex=True)
    .str.replace(r'\(.*?\)', '', regex=True)
    .str.replace(r'[^a-z\s]', '', regex=True)
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/4045077458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maharashtra['district_clean'] = (

# %%
mh_district_standard_map = {
    "aurangabad": "Chhatrapati Sambhajinagar",
    "chhatrapati sambhajinagar": "Chhatrapati Sambhajinagar",
    "chatrapati sambhaji nagar": "Chhatrapati Sambhajinagar",

    "ahilyanagar": "Ahmednagar",
    "ahmadnagar": "Ahmednagar",
    "ahmednagar": "Ahmednagar",
    "ahmed nagar": "Ahmednagar",

    "bid": "Beed",
    "beed": "Beed",

    "buldana": "Buldhana",
    "buldhana": "Buldhana",

    "osmanabad": "Dharashiv",
    "dharashiv": "Dharashiv",

    "gondiya": "Gondia",
    "gondiya *": "Gondia",
    "gondia": "Gondia",

    "raigarh(mh)": "Raigad",
    "raigad": "Raigad",

    "nandurbar *": "Nandurbar",
    "nandurbar": "Nandurbar",

    "hingoli *": "Hingoli",
    "hingoli": "Hingoli",

    "washim *": "Washim",
    "washim": "Washim",

    "mumbai suburban": "Mumbai Suburban",
    "mumbai( sub urban )": "Mumbai Suburban",

    "mumbai": "Mumbai City",
    "mumbai city": "Mumbai City"
}

# %%
df_Maharashtra['district_clean'] = (
    df_Maharashtra['district']
    .apply(clean_name)
    .map(mh_district_standard_map)
    .fillna(df_Maharashtra['district'])
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/2727463810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maharashtra['district_clean'] = (

# %%
## Remaining unmapped
df_Maharashtra[df_Maharashtra['district_clean'].isna()]['district'].unique()
# count check 
df_Maharashtra['district_clean'].nunique()
# Out:
# 40

# %%
df_Maharashtra.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# new_date          0
# state_clean       0
# district_clean    0
# dtype: int64

# %%
df_Maharashtra
# Out:
#                date        state    district  pincode  age_0_5  age_5_17  \
# 12       09-03-2025  Maharashtra  Aurangabad   431001       42        46
# 43       15-03-2025  Maharashtra    Parbhani   431401       17        14
# 67       20-03-2025  Maharashtra       Thane   421503       19        13
# 78       20-03-2025  Maharashtra  Aurangabad   431001      134        38
# 151      27-03-2025  Maharashtra  Aurangabad   431001       20        19
# ...             ...          ...         ...      ...      ...       ...
# 1004434  31-12-2025  Maharashtra    Yavatmal   445105        2         1
# 1004435  31-12-2025  Maharashtra    Yavatmal   445109        6         1
# 1004436  31-12-2025  Maharashtra    Yavatmal   445205        4         2
# 1004437  31-12-2025  Maharashtra    Yavatmal   445211        1         0
# 1004438  31-12-2025  Maharashtra    Yavatmal   445401        2         1
#
#          age_18_greater  new_date  state_clean             district_clean
# ...

# %%
## total enrolment by district in Maharashtra
df_Maharashtra_dist_level = df_Maharashtra.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()

# %%
df_Maharashtra['total_enrollment'] = (
    df_Maharashtra['age_0_5'] +
    df_Maharashtra['age_5_17'] +
    df_Maharashtra['age_18_greater']
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/3053212460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maharashtra['total_enrollment'] = (

# %%
df_Maharashtra
# Out:
#                date        state    district  pincode  age_0_5  age_5_17  \
# 12       09-03-2025  Maharashtra  Aurangabad   431001       42        46
# 43       15-03-2025  Maharashtra    Parbhani   431401       17        14
# 67       20-03-2025  Maharashtra       Thane   421503       19        13
# 78       20-03-2025  Maharashtra  Aurangabad   431001      134        38
# 151      27-03-2025  Maharashtra  Aurangabad   431001       20        19
# ...             ...          ...         ...      ...      ...       ...
# 1004434  31-12-2025  Maharashtra    Yavatmal   445105        2         1
# 1004435  31-12-2025  Maharashtra    Yavatmal   445109        6         1
# 1004436  31-12-2025  Maharashtra    Yavatmal   445205        4         2
# 1004437  31-12-2025  Maharashtra    Yavatmal   445211        1         0
# 1004438  31-12-2025  Maharashtra    Yavatmal   445401        2         1
#
#          age_18_greater  new_date  state_clean             district_clean  \
# ...

# %%
# enrolment top 10 district 
df_district_level_mh = df_Maharashtra["district_clean"].head(10)

# %%
## total enrolment by district in uttar pradesh
state_summary_mh = df_Maharashtra.groupby('district_clean')[[
    'age_0_5', 'age_5_17', 'age_18_greater'
]].sum() ## means of all age group by district

state_summary_mh['total_enrollment'] = (
    state_summary_mh['age_0_5'] +
    state_summary_mh['age_5_17'] +
    state_summary_mh['age_18_greater'] ## total enrolment by district
)

top10_districts_mh = state_summary_mh.sort_values(
    by='total_enrollment', ascending=False
).head(10)

# %%
## bar plot for top 10 states
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.barplot(
    x=top10_districts_mh.index,
    y=top10_districts_mh['total_enrollment'],
    palette='viridis'
)
plt.title('Top 10 Districts by Total Aadhar Enrollments in Maharashtra')
plt.xlabel('Districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1953306520.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top10_districts_mh['children_enrollment'] = (
    top10_districts_mh['age_0_5'] +
    top10_districts_mh['age_5_17']
)

# %%
# Stacked bar plot for age group comparison
plt.figure(figsize=(14,6))
top10_districts_mh[['children_enrollment', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Top 10 districts: Children vs Adults Enrollment')
plt.xlabel('districts')
plt.ylabel('Total Enrollments')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_Maharashtra['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
pincode_check_mh = df_Maharashtra.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincodes')
pincode_check_mh
# Out:
#                district_clean  unique_pincodes
# 0                  Ahmednagar               90
# 1                       Akola               29
# 2                    Amravati               42
# 3                        Beed               28
# 4                    Bhandara               21
# 5                    Buldhana               32
# 6                  Chandrapur               33
# 7   Chatrapati Sambhaji Nagar                3
# 8   Chhatrapati Sambhajinagar               44
# 9                   Dharashiv               28
# 10                      Dhule               29
# 11                 Gadchiroli               15
# 12                     Gondia               14
# 13                    Hingoli               14
# 14                    Jalgaon               62
# 15                      Jalna               26
# 16                   Kolhapur               78
# 17                      Latur               24
# 18                Mumbai City              109
# ...

# %%
pin_district_count_mh = (
    df_Maharashtra.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count_mh
# Out:
#       pincode  district_count
# 0      400001               2
# 1      400002               1
# 2      400003               1
# 3      400004               1
# 4      400005               1
# ...       ...             ...
# 1575   445307               1
# 1576   445308               1
# 1577   445323               1
# 1578   445401               1
# 1579   445402               1
#
# [1580 rows x 2 columns]

# %%
problem_pins_mh = pin_district_count_mh[
    pin_district_count_mh['district_count'] > 1
]

# %%
problem_pins_mh
## ek pin code 2 district se belong kr skta hai theek ye govt ki website pr hai
# Out:
#       pincode  district_count
# 0      400001               2
# 11     400012               2
# 22     400024               3
# 27     400029               2
# 31     400033               2
# ...       ...             ...
# 1472   444108               2
# 1474   444110               2
# 1494   444405               2
# 1497   444501               2
# 1499   444503               2
#
# [213 rows x 2 columns]

# %%
df_flagged_mh = df_Maharashtra.merge(
    problem_pins_mh[['pincode']],
    on='pincode',
    how='inner'
)

# %%
## ye sab o hai jissme ek district ke 2 pincode hai
## yha se hum pta kr skte hai kiss district me jda use ho rha hai 
df_flagged_mh
# Out:
#              date        state    district  pincode  age_0_5  age_5_17  \
# 0      09-03-2025  Maharashtra  Aurangabad   431001       42        46
# 1      20-03-2025  Maharashtra  Aurangabad   431001      134        38
# 2      27-03-2025  Maharashtra  Aurangabad   431001       20        19
# 3      01-04-2025  Maharashtra     Hingoli   431512      243        22
# 4      01-04-2025  Maharashtra     Palghar   401209      174        90
# ...           ...          ...         ...      ...      ...       ...
# 16616  31-12-2025  Maharashtra       Thane   401209        4         5
# 16617  31-12-2025  Maharashtra       Thane   401302        0         1
# 16618  31-12-2025  Maharashtra       Thane   401404        1         0
# 16619  31-12-2025  Maharashtra       Thane   421303        2         0
# 16620  31-12-2025  Maharashtra      Wardha   442302        3         0
#
#        age_18_greater  new_date  state_clean             district_clean  \
# ...

# %%
flagged_pincode_mh=df_flagged_mh.groupby(['district_clean','pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()
#flagged_pincode_mh.to_excel('flagged_pincode_domain.xlsx')

# %%
flagged_pincode_mh['total_enrollment']=flagged_pincode_mh['age_0_5']+flagged_pincode_mh['age_5_17']+flagged_pincode_mh['age_18_greater']
flagged_pincode_mh
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 0       Ahmednagar   400037        2         2               0
# 1       Ahmednagar   412210       32         5               0
# 2            Akola   444105        3         0               0
# 3            Akola   444107      152        20               0
# 4            Akola   444108      177        32               1
# ..             ...      ...      ...       ...             ...
# 492         Washim   444105      352        28               5
# 493         Washim   444107       32         4               0
# 494         Washim   444110       80         5               4
# 495         Washim   444405        3         1               0
# 496         Washim   444503      273        21               4
#
#      total_enrollment
# 0                   4
# 1                  37
# 2                   3
# 3                 172
# 4                 210
# ..                ...
# 492               385
# ...

# %%
idx = flagged_pincode_mh.groupby('pincode')['total_enrollment'].idxmax()
df_filtered_mh = flagged_pincode_mh.loc[idx]
df_filtered_mh
# Out:
#       district_clean  pincode  age_0_5  age_5_17  age_18_greater  \
# 77       Mumbai City   400001       44        13               6
# 78       Mumbai City   400012      251        21               9
# 154  Mumbai Suburban   400024       51        12               2
# 80       Mumbai City   400029       39         9               0
# 81       Mumbai City   400033      129        28               2
# ..               ...      ...      ...       ...             ...
# 4              Akola   444108      177        32               1
# 494           Washim   444110       80         5               4
# 6              Akola   444405       56         2               0
# 7              Akola   444501      252        23               3
# 496           Washim   444503      273        21               4
#
#      total_enrollment
# 77                 63
# 78                281
# 154                65
# 80                 48
# 81                159
# ..                ...
# ...

# %%
df_Maharashtra['pin_multi_district_flag']=(
    df_Maharashtra.groupby('pincode')['district_clean']
    .transform('nunique')>1
)
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/1346061413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maharashtra['pin_multi_district_flag']=(

# %%
pin_district_map_mh = (
    df_Maharashtra[df_Maharashtra['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']  # noqa: SC100
    .unique()
    .reset_index()
)

# %%
## monthly enrolment check 
df_Maharashtra['month'] = df_Maharashtra['new_date'].astype(str).str[4:6]
df_Maharashtra
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_17393/4211111142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maharashtra['month'] = df_Maharashtra['new_date'].astype(str).str[4:6]
#                date        state    district  pincode  age_0_5  age_5_17  \
# 12       09-03-2025  Maharashtra  Aurangabad   431001       42        46
# 43       15-03-2025  Maharashtra    Parbhani   431401       17        14
# 67       20-03-2025  Maharashtra       Thane   421503       19        13
# 78       20-03-2025  Maharashtra  Aurangabad   431001      134        38
# 151      27-03-2025  Maharashtra  Aurangabad   431001       20        19
# ...             ...          ...         ...      ...      ...       ...
# ...

# %%
df_Maharashtra_cleaned_mh=df_Maharashtra.drop(columns=['date','district','state'], axis=1)
df_Maharashtra_cleaned_mh
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date  state_clean  \
# 12        431001       42        46              12  20250309  Maharashtra
# 43        431401       17        14              37  20250315  Maharashtra
# 67        421503       19        13              15  20250320  Maharashtra
# 78        431001      134        38              18  20250320  Maharashtra
# 151       431001       20        19              16  20250327  Maharashtra
# ...          ...      ...       ...             ...       ...          ...
# 1004434   445105        2         1               0  20251231  Maharashtra
# 1004435   445109        6         1               0  20251231  Maharashtra
# 1004436   445205        4         2               0  20251231  Maharashtra
# 1004437   445211        1         0               0  20251231  Maharashtra
# 1004438   445401        2         1               0  20251231  Maharashtra
#
# ...

# %%
df_Maharashtra_dist_level_mh = df_Maharashtra_cleaned_mh.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater']].sum()
df_Maharashtra_dist_level_mh['total_enrollment'] = df_Maharashtra_dist_level_mh['age_0_5'] + df_Maharashtra_dist_level_mh['age_5_17'] + df_Maharashtra_dist_level_mh['age_18_greater']

# %%
df_Maharashtra_dist_level_mh.shape
# Out:
# (40, 4)

# %%
df_Maharashtra_dist_level_mh
# Out:
#                            age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Ahmednagar                    9840      2560             157             12557
# Akola                         3966       693              49              4708
# Amravati                      5783      1025             107              6915
# Beed                          7893      2590             270             10753
# Bhandara                      1842        55               6              1903
# Buldhana                      6812      1205             142              8159
# Chandrapur                    4014       375              86              4475
# Chatrapati Sambhaji Nagar      114        81              16               211
# Chhatrapati Sambhajinagar    12785      5239             379             18403
# Dharashiv                     3392       741              37              4170
# Dhule                         7244      4842             519             12605
# ...

# %%
df_Maharashtra_dist_level_mh.sort_values("total_enrollment",ascending=False).reset_index()
# df_Maharashtra_dist_level_mh.to_excel('maharashtra_district_level_enrolment.xlsx')
# Out:
#                district_clean  age_0_5  age_5_17  age_18_greater  \
# 0                       Thane    29092     13629             967
# 1                        Pune    24088      6536            1139
# 2                      Nashik    16262      5802             304
# 3   Chhatrapati Sambhajinagar    12785      5239             379
# 4             Mumbai Suburban    12480      4946             790
# 5                 Mumbai City    12908      4330             243
# 6                     Jalgaon    10454      2579             227
# 7                       Dhule     7244      4842             519
# 8                  Ahmednagar     9840      2560             157
# 9                     Solapur     9537      2495             260
# 10                     Nanded     9164      2447             336
# 11                     Nagpur    10093      1502             233
# 12                       Beed     7893      2590             270
# ...

# %%
df_Maharashtra_dist_level_mh = df_Maharashtra_dist_level_mh.head(10)
df_Maharashtra_dist_level_mh
# Out:
#                            age_0_5  age_5_17  age_18_greater  total_enrollment
# district_clean
# Ahmednagar                    9840      2560             157             12557
# Akola                         3966       693              49              4708
# Amravati                      5783      1025             107              6915
# Beed                          7893      2590             270             10753
# Bhandara                      1842        55               6              1903
# Buldhana                      6812      1205             142              8159
# Chandrapur                    4014       375              86              4475
# Chatrapati Sambhaji Nagar      114        81              16               211
# Chhatrapati Sambhajinagar    12785      5239             379             18403
# Dharashiv                     3392       741              37              4170

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.lineplot(data=df_Maharashtra_dist_level_mh[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Districts in Maharashtra - Age Group Enrollment Comparison')
plt.xlabel('Districts')
plt.ylabel('Number of Enrollments')
plt.legend(title='Age Groups', labels=['Age 0-5', 'Age 5-17', 'Age 18 and above'])
plt.xticks(ticks=range(len(df_Maharashtra_dist_level_mh.index)), labels=df_Maharashtra_dist_level_mh.index, rotation=45)
plt.show()

# %%
df_Maharashtra_pincode_level = df_Maharashtra_cleaned_mh.groupby('pincode')[['age_0_5','age_5_17','age_18_greater']].sum()
df_Maharashtra_pincode_level['total_enrollment'] = df_Maharashtra_pincode_level['age_0_5'] + df_Maharashtra_pincode_level['age_5_17'] + df_Maharashtra_pincode_level['age_18_greater']
df_Maharashtra_pincode_level.shape
# Out:
# (1580, 4)

# %%
df_Maharashtra_pincode_level.sort_values("total_enrollment",ascending=False).reset_index()
# df_Maharashtra_pincode_level.to_excel('Maharashtra_pincode_level_enrolment.xlsx')

df_Maharashtra_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 400001        44        14               6                64
# 400002        95        21               7               123
# 400003       165        18               6               189
# 400004       180        29               4               213
# 400005       143        32               7               182
# ...          ...       ...             ...               ...
# 445307        28         2               0                30
# 445308        31         6               1                38
# 445323        68        23               0                91
# 445401        65        16               2                83
# 445402        94        13               4               111
#
# [1580 rows x 4 columns]

# %%
df_Maharashtra_pincode_level1 = df_Maharashtra_pincode_level.head(10)
df_Maharashtra_pincode_level1
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enrollment
# pincode
# 400001        44        14               6                64
# 400002        95        21               7               123
# 400003       165        18               6               189
# 400004       180        29               4               213
# 400005       143        32               7               182
# 400006        67        13               7                87
# 400007        68         8               2                78
# 400008       421        90               6               517
# 400009       132        23               3               158
# 400010       179        58               5               242

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=df_Maharashtra_pincode_level1[['age_0_5','age_5_17','age_18_greater']])
plt.title('Top 10 Pincodes in Maharashtra - Age Group Enrollment Comparison')
plt.xlabel('Pincodes')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## monthly enrolment trend in bihar
df_Maharashtra_monthly = df_Maharashtra_cleaned_mh.groupby('month')[['age_0_5','age_5_17','age_18_greater']].sum()
df_Maharashtra_monthly['total_enrollment'] = df_Maharashtra_monthly['age_0_5'] + df_Maharashtra_monthly['age_5_17'] + df_Maharashtra_monthly['age_18_greater']
df_Maharashtra_monthly.shape
# Out:
# (9, 4)

# %%
df_Maharashtra_monthly
df_Maharashtra_monthly.sort_values("total_enrollment",ascending=False).reset_index()
# Out:
#   month  age_0_5  age_5_17  age_18_greater  total_enrollment
# 0    09    73837     27751             753            102341
# 1    11    58064     12039            1783             71886
# 2    12    49960      6857             774             57591
# 3    07    34468     18536            1763             54767
# 4    10    41040      9032             933             51005
# 5    06     6521      3518             610             10649
# 6    04     7986      1901             704             10591
# 7    05     6706      2352             791              9849
# 8    03      232       130              98               460

# %%
sns.lineplot(data=df_Maharashtra_monthly)
# Out:
# <Axes: xlabel='month'>

# %%
## Stacked bar plot for age group comparison
plt.figure(figsize=(10,6))
df_Maharashtra_monthly[['age_0_5', 'age_5_17', 'age_18_greater']].plot(
    kind='bar',
    stacked=True,
    colormap='viridis'
)
plt.title('Maharashtra Monthly Aadhar Enrollments by Age Group')
plt.xlabel('Month')
plt.ylabel('Number of Enrollments')
plt.show()

# %%
## # #
